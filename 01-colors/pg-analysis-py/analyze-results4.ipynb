# %%
import json
import pandas as pd
import sqlite3

# %%
jsonLines = open('../color-word-analysis-py/pg-results.jsonl').read().split('\n')

# %%
decodedLines = []
for line in jsonLines: 
    try: 
        decoded = json.loads(line)
        decodedLines.append(decoded)
    except: 
        continue

# %%
len(decodedLines)
# Out:
# 1209

# %%
decodedLines[0]
# Out:
# {'2374.0': {'length': 565553,
#   'totalNColors': 713,
#   'colorCounts': {'sunshine': 14,
#    'marble': 4,
#    'gilded': 1,
#    'moonlight': 8,
#    'white': 103,
#    'green': 43,
#    'cedar': 3,
#    'elm': 4,
#    'chestnut': 2,
#    'gray': 6,
#    'crimson': 13,
#    'rose': 9,
#    'golden': 44,
#    'silver': 10,
#    'dark': 87,
#    'apple': 3,
#    'strawberry': 3,
#    'wheat': 1,
#    'leaf': 6,
#    'blue': 17,
#    'violet': 4,
#    'red': 3,
#    'berry': 1,
#    'sky': 26,
#    'pale': 61,
#    'shadow': 13,
#    'grass': 16,
#    'claret': 1,
#    'storm': 8,
#    'earth': 16,
#    'cloud': 2,
#    'pink': 8,
#    'smoke': 1,
#    'sunbeam': 2,
#    'foliage': 3,
#    'purple': 4,
#    'foxglove': 1,
#    'sea': 25,
#    'steel': 1,
#    'forest': 3,
#    'wine': 4,
#    'bluebell': 1,
#    'yellow': 6,
#    'sand': 4,
#    'straw': 1,
#    'hay': 2,
#    'tea': 2,
#    'cream': 1,
#    'gold': 9,
#    'stone': 2,
#    'ocean': 4,
#    'coral': 1,
#    'pearl': 3,
#    'orange': 1,
#    'dust': 1,
#    'peace': 3,
#    'black': 7,
#    'velvet': 1,
#    'opal': 3,
#    'desert': 2,
#    'pomegranate': 2,
#    'verbena': 2,
#    'blossom': 2,
#    'scarlet': 2,
#    'beech': 1,
#    'blush': 1,
#    'iron': 2,
#    'autumn': 2,
#    'lime': 2,
#    'caprice': 1,
#    'blood': 2,
#    'lake': 1},
#   'colorHexes': {'sunshine': '#EAE679',
#    'marble': '#3A4B47',
#    'gilded': '#E3A857',
#    'moonlight': '#ECD5C5',
#    'white': '#ffffff',
#    'green': '#15b01a',
#    'cedar': '#79443B',
#    'elm': '#8F9779',
#    'chestnut': '#742802',
#    'gray': '#555555',
#    'crimson': '#8c000f',
#    'rose': '#cf6275',
#    'golden': '#f5bf03',
#    'silver': '#c5c9c7',
#    'dark': '#1b2431',
#    'apple': '#6ecb3c',
#    'strawberry': '#fb2943',
#    'wheat': '#fbdd7e',
#    'leaf': '#71aa34',
#    'blue': '#0343df',
#    'violet': '#9a0eea',
#    'red': '#e50000',
#    'berry': '#990f4b',
#    'sky': '#82cafc',
#    'pale': '#fff9d0',
#    'shadow': '#8F817F',
#    'grass': '#5cac2d',
#    'claret': '#680018',
#    'storm': '#536878',
#    'earth': '#a2653e',
#    'cloud': '#536878',
#    'pink': '#ff81c0',
#    'smoke': '#555555',
#    'sunbeam': '#C2B280',
#    'foliage': '#7E9F2E',
#    'purple': '#7e1e9c',
#    'foxglove': '#604E81',
#    'sea': '#3c9992',
#    'steel': '#738595',
#    'forest': '#0b5509',
#    'wine': '#80013f',
#    'bluebell': '#00304E',
#    'yellow': '#ffff14',
#    'sand': '#e2ca76',
#    'straw': '#fcf679',
#    'hay': '#B9B57D',
#    'tea': '#65ab7c',
#    'cream': '#ffffc2',
#    'gold': '#dbb40c',
#    'stone': '#ada587',
#    'ocean': '#017b92',
#    'coral': '#fc5a50',
#    'pearl': '#F0EAD6',
#    'orange': '#f97306',
#    'dust': '#b2996e',
#    'peace': '#F0EAD6',
#    'black': '#000000',
#    'velvet': '#750851',
#    'opal': '#317873',
#    'desert': '#ccad60',
#    'pomegranate': '#722F37',
#    'verbena': '#915C83',
#    'blossom': '#EBE8A4',
#    'scarlet': '#be0119',
#    'beech': '#57554C',
#    'blush': '#f29e8e',
#    'iron': '#222222',
#    'autumn': '#363527',
#    'lime': '#aaff32',
#    'caprice': '#D6CADD',
#    'blood': '#770001',
#    'lake': '#A8516E'},
#   'colorLocs': {'Ronald--"good': [[2312, 2325]],
#    'sunshine': [[4460, 4468],
#     [19480, 19488],
#     [30851, 30859],
#     [49063, 49071],
#     [49776, 49784],
#     [83244, 83252],
#     [122262, 122270],
#     [159301, 159309],
#     [170878, 170886],
#     [176680, 176688],
#     [215249, 215257],
#     [498363, 498371],
#     [541430, 541438],
#     [560157, 560165]],
#    'marble': [[4689, 4695],
#     [360090, 360096],
#     [386282, 386288],
#     [513709, 513715]],
#    'gilded': [[5277, 5283]],
#    'moonlight': [[7466, 7475],
#     [376787, 376796],
#     [438672, 438681],
#     [449426, 449435],
#     [454440, 454449],
#     [483566, 483575],
#     [486762, 486771],
#     [490437, 490446]],
#    'white': [[9684, 9689],
#     [22217, 22222],
#     [23976, 23981],
#     [24432, 24437],
#     [30248, 30253],
#     [32517, 32522],
#     [48061, 48066],
#     [51417, 51422],
#     [53422, 53427],
#     [61227, 61232],
#     [61859, 61864],
#     [62962, 62967],
#     [63014, 63019],
#     [69495, 69500],
#     [78441, 78446],
#     [80420, 80425],
#     [80704, 80709],
#     [82450, 82455],
#     [84015, 84020],
#     [88406, 88411],
#     [97064, 97069],
#     [101700, 101705],
#     [111508, 111513],
#     [128813, 128818],
#     [157772, 157777],
#     [159211, 159216],
#     [159484, 159489],
#     [161899, 161904],
#     [165359, 165364],
#     [166367, 166372],
#     [167232, 167237],
#     [170396, 170401],
#     [170851, 170856],
#     [171200, 171205],
#     [173880, 173885],
#     [174644, 174649],
#     [175063, 175068],
#     [175968, 175973],
#     [177826, 177831],
#     [178443, 178448],
#     [178798, 178803],
#     [202207, 202212],
#     [205302, 205307],
#     [211981, 211986],
#     [212821, 212826],
#     [212938, 212943],
#     [213328, 213333],
#     [215193, 215198],
#     [224459, 224464],
#     [233932, 233937],
#     [238025, 238030],
#     [239086, 239091],
#     [240081, 240086],
#     [249340, 249345],
#     [255859, 255864],
#     [260568, 260573],
#     [277480, 277485],
#     [291307, 291312],
#     [300478, 300483],
#     [305689, 305694],
#     [305766, 305771],
#     [305874, 305879],
#     [308647, 308652],
#     [327080, 327085],
#     [330067, 330072],
#     [330080, 330085],
#     [330093, 330098],
#     [352391, 352396],
#     [354738, 354743],
#     [355119, 355124],
#     [361104, 361109],
#     [369250, 369255],
#     [381877, 381882],
#     [382022, 382027],
#     [382814, 382819],
#     [383428, 383433],
#     [385722, 385727],
#     [386236, 386241],
#     [386375, 386380],
#     [393065, 393070],
#     [407895, 407900],
#     [416119, 416124],
#     [419377, 419382],
#     [421747, 421752],
#     [430264, 430269],
#     [460777, 460782],
#     [461878, 461883],
#     [463091, 463096],
#     [476261, 476266],
#     [482161, 482166],
#     [495942, 495947],
#     [502192, 502197],
#     [507474, 507479],
#     [509306, 509311],
#     [509957, 509962],
#     [511075, 511080],
#     [512351, 512356],
#     [513342, 513347],
#     [523599, 523604],
#     [525371, 525376],
#     [532543, 532548],
#     [541378, 541383],
#     [558767, 558772]],
#    'rise': [[15136, 15140],
#     [47728, 47732],
#     [53125, 53129],
#     [61735, 61739],
#     [66899, 66903],
#     [136857, 136861],
#     [149846, 149850],
#     [161280, 161284],
#     [178195, 178199],
#     [178833, 178837],
#     [190706, 190710],
#     [207614, 207618],
#     [249200, 249204],
#     [250005, 250009],
#     [262514, 262518],
#     [267556, 267560],
#     [296734, 296738],
#     [300868, 300872],
#     [308572, 308576],
#     [324110, 324114],
#     [339281, 339285],
#     [352577, 352581],
#     [369843, 369847],
#     [375263, 375267],
#     [377276, 377280],
#     [464716, 464720],
#     [478540, 478544],
#     [483449, 483453],
#     [485959, 485963],
#     [492697, 492701]],
#    'green': [[18090, 18095],
#     [22889, 22894],
#     [33669, 33674],
#     [33742, 33747],
#     [40814, 40819],
#     [64244, 64249],
#     [69578, 69583],
#     [73714, 73719],
#     [79517, 79522],
#     [79815, 79820],
#     [80376, 80381],
#     [126098, 126103],
#     [128951, 128956],
#     [171224, 171229],
#     [171360, 171365],
#     [171826, 171831],
#     [205030, 205035],
#     [212395, 212400],
#     [216114, 216119],
#     [225476, 225481],
#     [232067, 232072],
#     [278574, 278579],
#     [308902, 308907],
#     [313001, 313006],
#     [332653, 332658],
#     [354768, 354773],
#     [375560, 375565],
#     [384614, 384619],
#     [420351, 420356],
#     [476357, 476362],
#     [486493, 486498],
#     [486726, 486731],
#     [496967, 496972],
#     [497565, 497570],
#     [499155, 499160],
#     [507046, 507051],
#     [507436, 507441],
#     [507542, 507547],
#     [541221, 541226],
#     [546107, 546112],
#     [550183, 550188],
#     [550294, 550299],
#     [556688, 556693]],
#    'cedar': [[18480, 18485], [474406, 474411], [476817, 476822]],
#    'elm': [[18553, 18556],
#     [216607, 216610],
#     [231863, 231866],
#     [257489, 257492]],
#    'chestnut': [[18596, 18604], [486603, 486611]],
#    'gray': [[18954, 18958],
#     [179601, 179605],
#     [216829, 216833],
#     [330134, 330138],
#     [345883, 345887],
#     [497182, 497186]],
#    'crimson': [[22248, 22255],
#     [24026, 24033],
#     [24871, 24878],
#     [32550, 32557],
#     [119685, 119692],
#     [210747, 210754],
#     [222630, 222637],
#     [290378, 290385],
#     [305804, 305811],
#     [316310, 316317],
#     [366072, 366079],
#     [381933, 381940],
#     [468907, 468914]],
#    'rose': [[22269, 22273],
#     [31174, 31178],
#     [57992, 57996],
#     [63096, 63100],
#     [139990, 139994],
#     [229050, 229054],
#     [293147, 293151],
#     [367687, 367691],
#     [369937, 369941]],
#    'golden': [[22326, 22332],
#     [26395, 26401],
#     [36087, 36093],
#     [57692, 57698],
#     [115396, 115402],
#     [116437, 116443],
#     [128796, 128802],
#     [137856, 137862],
#     [143517, 143523],
#     [172327, 172333],
#     [172772, 172778],
#     [173242, 173248],
#     [177786, 177792],
#     [191164, 191170],
#     [191562, 191568],
#     [207732, 207738],
#     [212026, 212032],
#     [212731, 212737],
#     [221872, 221878],
#     [230713, 230719],
#     [260428, 260434],
#     [275340, 275346],
#     [297530, 297536],
#     [299939, 299945],
#     [308866, 308872],
#     [309564, 309570],
#     [310266, 310272],
#     [310490, 310496],
#     [312218, 312224],
#     [317523, 317529],
#     [328673, 328679],
#     [340003, 340009],
#     [350377, 350383],
#     [368611, 368617],
#     [407708, 407714],
#     [448109, 448115],
#     [449454, 449460],
#     [454492, 454498],
#     [457143, 457149],
#     [472459, 472465],
#     [480019, 480025],
#     [498867, 498873],
#     [522988, 522994],
#     [565349, 565355]],
#    'silver': [[23514, 23520],
#     [34424, 34430],
#     [58063, 58069],
#     [83179, 83185],
#     [269853, 269859],
#     [368002, 368008],
#     [388913, 388919],
#     [457626, 457632],
#     [499787, 499793],
#     [563741, 563747]],
#    'dark': [[24452, 24456],
#     [24507, 24511],
#     [24944, 24948],
#     [25949, 25953],
#     [30390, 30394],
#     [31229, 31233],
#     [35076, 35080],
#     [37399, 37403],
#     [51090, 51094],
#     [51393, 51397],
#     [65897, 65901],
#     [80486, 80490],
#     [82406, 82410],
#     [108011, 108015],
#     [108630, 108634],
#     [111130, 111134],
#     [115153, 115157],
#     [119945, 119949],
#     [121167, 121171],
#     [124651, 124655],
#     [134997, 135001],
#     [135077, 135081],
#     [143191, 143195],
#     [144577, 144581],
#     [147080, 147084],
#     [148783, 148787],
#     [151914, 151918],
#     [160766, 160770],
#     [165375, 165379],
#     [166985, 166989],
#     [170132, 170136],
#     [173897, 173901],
#     [175039, 175043],
#     [177250, 177254],
#     [182329, 182333],
#     [189198, 189202],
#     [210837, 210841],
#     [210910, 210914],
#     [221266, 221270],
#     [233953, 233957],
#     [241958, 241962],
#     [260607, 260611],
#     [272044, 272048],
#     [300453, 300457],
#     [305846, 305850],
#     [313629, 313633],
#     [316043, 316047],
#     [329445, 329449],
#     [355188, 355192],
#     [356951, 356955],
#     [362245, 362249],
#     [367183, 367187],
#     [374917, 374921],
#     [375469, 375473],
#     [376871, 376875],
#     [381983, 381987],
#     [382893, 382897],
#     [386340, 386344],
#     [390652, 390656],
#     [394851, 394855],
#     [406117, 406121],
#     [412912, 412916],
#     [422910, 422914],
#     [424390, 424394],
#     [440869, 440873],
#     [441265, 441269],
#     [441966, 441970],
#     [442023, 442027],
#     [447737, 447741],
#     [453175, 453179],
#     [476290, 476294],
#     [483786, 483790],
#     [491150, 491154],
#     [494276, 494280],
#     [496014, 496018],
#     [499490, 499494],
#     [509347, 509351],
#     [514103, 514107],
#     [532679, 532683],
#     [551009, 551013],
#     [554751, 554755],
#     [560866, 560870],
#     [563185, 563189],
#     [564779, 564783],
#     [565034, 565038],
#     [565048, 565052],
#     [565232, 565236]],
#    'apple': [[24842, 24847], [25422, 25427], [317450, 317455]],
#    'strawberry': [[25291, 25303], [231765, 231775], [360941, 360951]],
#    'wheat': [[26378, 26383]],
#    'leaf': [[29352, 29356],
#     [81720, 81724],
#     [81731, 81735],
#     [131808, 131812],
#     [212983, 212987],
#     [518088, 518092]],
#    'blue': [[29372, 29376],
#     [78195, 78199],
#     [78457, 78461],
#     [80436, 80440],
#     [110314, 110318],
#     [119726, 119730],
#     [134799, 134803],
#     [170670, 170674],
#     [211838, 211842],
#     [261613, 261617],
#     [296032, 296036],
#     [354725, 354729],
#     [375653, 375657],
#     [379234, 379238],
#     [384104, 384108],
#     [401102, 401106],
#     [507529, 507533]],
#    'violet': [[29686, 29692],
#     [212748, 212754],
#     [407855, 407861],
#     [549138, 549144]],
#    'red': [[31191, 31194], [32645, 32648], [202188, 202191]],
#    'berry': [[32558, 32565]],
#    'sky': [[33788, 33791],
#     [78191, 78194],
#     [89796, 89799],
#     [110520, 110523],
#     [120130, 120133],
#     [134804, 134807],
#     [177911, 177914],
#     [200684, 200687],
#     [211769, 211772],
#     [237266, 237269],
#     [239030, 239033],
#     [296028, 296031],
#     [354730, 354733],
#     [367938, 367941],
#     [375731, 375734],
#     [393323, 393326],
#     [411732, 411735],
#     [440914, 440917],
#     [454552, 454555],
#     [481951, 481954],
#     [497208, 497211],
#     [498041, 498044],
#     [498849, 498852],
#     [523741, 523744],
#     [532421, 532424],
#     [562548, 562551]],
#    'pale': [[36192, 36196],
#     [50411, 50415],
#     [74149, 74153],
#     [79432, 79436],
#     [94845, 94849],
#     [95445, 95449],
#     [103143, 103147],
#     [132486, 132490],
#     [134976, 134980],
#     [136464, 136468],
#     [147469, 147473],
#     [148118, 148122],
#     [160745, 160749],
#     [168654, 168658],
#     [181314, 181318],
#     [182033, 182037],
#     [225226, 225230],
#     [231760, 231764],
#     [233321, 233325],
#     [237856, 237860],
#     [243352, 243356],
#     [254165, 254169],
#     [273213, 273217],
#     [278789, 278793],
#     [282223, 282227],
#     [283576, 283580],
#     [292179, 292183],
#     [308426, 308430],
#     [310019, 310023],
#     [317787, 317791],
#     [322565, 322569],
#     [343272, 343276],
#     [361171, 361175],
#     [366392, 366396],
#     [382875, 382879],
#     [388140, 388144],
#     [399183, 399187],
#     [404524, 404528],
#     [418577, 418581],
#     [419034, 419038],
#     [448004, 448008],
#     [456929, 456933],
#     [467651, 467655],
#     [468100, 468104],
#     [469661, 469665],
#     [476985, 476989],
#     [480968, 480972],
#     [495733, 495737],
#     [496896, 496900],
#     [497484, 497488],
#     [498134, 498138],
#     [500995, 500999],
#     [501750, 501754],
#     [502724, 502728],
#     [503940, 503944],
#     [505919, 505923],
#     [506106, 506110],
#     [507914, 507918],
#     [510298, 510302],
#     [514875, 514879],
#     [544380, 544384]],
#    'shadow': [[36209, 36215],
#     [51226, 51232],
#     [124639, 124645],
#     [216452, 216458],
#     [314630, 314636],
#     [366290, 366296],
#     [376330, 376336],
#     [376773, 376779],
#     [409536, 409542],
#     [420981, 420987],
#     [480260, 480266],
#     [533198, 533204],
#     [563209, 563215]],
#    'grass': [[41566, 41571],
#     [79821, 79826],
#     [172902, 172907],
#     [205195, 205200],
#     [205480, 205485],
#     [375566, 375571],
#     [486572, 486577],
#     [491194, 491199],
#     [496111, 496116],
#     [498694, 498699],
#     [531994, 531999],
#     [540686, 540691],
#     [550300, 550305],
#     [550678, 550683],
#     [556870, 556875],
#     [563657, 563662]],
#    'claret': [[43919, 43925]],
#    'storm': [[47059, 47064],
#     [53635, 53640],
#     [58589, 58594],
#     [153021, 153026],
#     [225414, 225419],
#     [328397, 328402],
#     [407972, 407977],
#     [511770, 511775]],
#    'earth': [[56950, 56955],
#     [105651, 105656],
#     [187159, 187164],
#     [197158, 197163],
#     [243862, 243867],
#     [243986, 243991],
#     [270031, 270036],
#     [325445, 325450],
#     [344633, 344638],
#     [362965, 362970],
#     [418165, 418170],
#     [474834, 474839],
#     [475157, 475162],
#     [492332, 492337],
#     [535936, 535941],
#     [546542, 546547]],
#    'cloud': [[57305, 57310], [124656, 124661]],
#    'pink': [[58272, 58276],
#     [116410, 116414],
#     [361176, 361180],
#     [375289, 375293],
#     [457255, 457259],
#     [503483, 503487],
#     [512054, 512058],
#     [512147, 512151]],
#    'smoke': [[59557, 59562]],
#    'sunbeam': [[63470, 63477], [115213, 115220]],
#    'hue': [[79579, 79582], [115403, 115406], [207739, 207742]],
#    'foliage': [[80382, 80389], [365045, 365052], [556694, 556701]],
#    'purple': [[80756, 80762],
#     [213298, 213304],
#     [231734, 231740],
#     [292120, 292126]],
#    'foxglove': [[80763, 80771]],
#    'sea': [[108000, 108003],
#     [170816, 170819],
#     [171053, 171056],
#     [171171, 171174],
#     [205234, 205237],
#     [211777, 211780],
#     [211918, 211921],
#     [214363, 214366],
#     [216042, 216045],
#     [216289, 216292],
#     [216579, 216582],
#     [218096, 218099],
#     [219033, 219036],
#     [221977, 221980],
#     [223074, 223077],
#     [225286, 225289],
#     [229860, 229863],
#     [239727, 239730],
#     [256185, 256188],
#     [277527, 277530],
#     [277767, 277770],
#     [336341, 336344],
#     [383636, 383639],
#     [385035, 385038],
#     [397782, 397785]],
#    'steel': [[115856, 115861]],
#    'vine': [[120239, 120243], [120807, 120811], [168450, 168454]],
#    'forest': [[131744, 131750], [205509, 205515], [498930, 498936]],
#    'wine': [[137609, 137613],
#     [308745, 308749],
#     [438272, 438276],
#     [516494, 516498]],
#    'bluebell': [[140072, 140080]],
#    'yellow': [[170494, 170500],
#     [170798, 170804],
#     [212551, 212557],
#     [218133, 218139],
#     [224787, 224793],
#     [369917, 369923]],
#    'sand': [[170501, 170505],
#     [170805, 170810],
#     [205329, 205334],
#     [224149, 224154]],
#    'straw': [[171609, 171614]],
#    'hay': [[172280, 172283], [317535, 317538]],
#    'sickle': [[172382, 172388], [340055, 340061]],
#    'tea': [[173237, 173240], [516910, 516913]],
#    'cream': [[173312, 173317]],
#    'meadow': [[174498, 174504],
#     [216491, 216497],
#     [231615, 231621],
#     [232073, 232079]],
#    'gold': [[211934, 211938],
#     [237861, 237865],
#     [238296, 238300],
#     [388904, 388908],
#     [416924, 416928],
#     [474898, 474902],
#     [492214, 492218],
#     [494378, 494382],
#     [521305, 521309]],
#    'stone': [[213538, 213543], [290862, 290867]],
#    'ocean': [[225120, 225125],
#     [225545, 225550],
#     [239950, 239955],
#     [241021, 241026]],
#    'coral': [[225156, 225161]],
#    'pearl': [[225241, 225246], [416911, 416916], [417388, 417393]],
#    'orange': [[261664, 261670]],
#    'frost': [[267202, 267207]],
#    'dust': [[268765, 268769]],
#    'peace': [[271755, 271760], [408402, 408407], [490130, 490135]],
#    'black': [[278713, 278718],
#     [440655, 440660],
#     [448981, 448986],
#     [449385, 449390],
#     [458104, 458109],
#     [548013, 548018],
#     [563286, 563291]],
#    'velvet': [[290429, 290435]],
#    'necklace': [[290727, 290735]],
#    'opal': [[290915, 290919], [291258, 291262], [292424, 292428]],
#    'desert': [[291616, 291622], [337271, 337277]],
#    'Rose': [[293306, 293310]],
#    'Moonlight': [[293348, 293357]],
#    'pomegranate': [[305937, 305948], [330232, 330243]],
#    'verbena': [[306050, 306057], [330265, 330272]],
#    'purple - red': [[308734, 308744]],
#    'blossom': [[309260, 309267], [366170, 366177]],
#    'fruit': [[317594, 317599]],
#    'scarlet': [[330528, 330535], [330824, 330831]],
#    'dusty': [[339870, 339875]],
#    'beech': [[340109, 340114]],
#    'elysium': [[344716, 344723]],
#    'blush': [[378276, 378281]],
#    'leave': [[420106, 420112], [474339, 474345]],
#    'iron': [[424776, 424780], [527617, 527621]],
#    'before,--if': [[444794, 444805]],
#    'autumn': [[473199, 473205], [540541, 540547]],
#    'lime': [[482778, 482782], [483120, 483124]],
#    'alder': [[498732, 498737]],
#    'caprice': [[500097, 500104]],
#    'blood': [[522925, 522930], [536715, 536720]],
#    'lake': [[543484, 543488]]}}}

# %%
countsDict = {}
for line in decodedLines: 
    bookId = list(line.keys())[0]
    counts = line[bookId]['colorCounts']
    countsDict[bookId] = counts

# %%
df = pd.DataFrame(countsDict)

# %%
conn = sqlite3.connect('/media/jon/Sekurkopioj/Corpora/pg-text-7.db')

# %%
def getMeta(bookId): 
    df = pd.read_sql('select * from meta where id=?', conn, params = [bookId])
    return df

# %%
df
# Out:
#            2374.0  2864.0  3622.0  3633.0  6036.0  6688.0  11990.0  18782.0  \
# sunshine     14.0     1.0     NaN     NaN     NaN    14.0      NaN      2.0
# marble        4.0     NaN     NaN     NaN     NaN     1.0      NaN      NaN
# gilded        1.0     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# moonlight     8.0     1.0     NaN     5.0     NaN     NaN      NaN      NaN
# white       103.0    39.0     4.0     8.0     7.0    34.0      NaN      9.0
# ...           ...     ...     ...     ...     ...     ...      ...      ...
# celadon       NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# monkshood     NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# rufous        NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# fiesta        NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# ivy           NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
#            20528.0  26494.0  ...  35079.0  23757.0  10551.0  18430.0  3477.0  \
# sunshine      11.0      NaN  ...      NaN      NaN      NaN      NaN     NaN
# marble         NaN      NaN  ...      1.0      NaN      NaN      NaN     NaN
# gilded         1.0      NaN  ...      NaN      NaN      NaN      NaN     NaN
# moonlight      1.0      1.0  ...      8.0      NaN      NaN      NaN     NaN
# white         26.0      8.0  ...     44.0     26.0     16.0     11.0     1.0
# ...            ...      ...  ...      ...      ...      ...      ...     ...
# celadon        NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN
# monkshood      NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN
# rufous         NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN
# fiesta         NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN
# ivy            NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN
#
#            45636.0  26785.0  17091.0  748.0  16376.0
# sunshine       NaN      NaN      NaN    7.0      1.0
# marble         2.0      4.0      NaN    1.0      6.0
# gilded         NaN      NaN      NaN    1.0      NaN
# moonlight      2.0      4.0      NaN    2.0      1.0
# white         19.0     36.0      NaN   50.0     12.0
# ...            ...      ...      ...    ...      ...
# celadon        NaN      NaN      NaN    NaN      NaN
# monkshood      NaN      NaN      NaN    NaN      NaN
# rufous         NaN      NaN      NaN    NaN      NaN
# fiesta         NaN      NaN      NaN    NaN      NaN
# ivy            NaN      NaN      NaN    NaN      NaN
#
# [438 rows x 1206 columns]

# %%
getMeta('2374.0').columns
# Out:
# Index(['', 'LCC', 'author', 'authoryearofbirth', 'authoryearofdeath',
#        'downloads', 'formats', 'id', 'languages', 'lcsh', 'title', 'type',
#        '_repo', '_version', 'alternative_title', 'contributor', 'covers',
#        'creator', 'description', 'edition_identifiers', 'edition_note',
#        'gutenberg_bookshelf', 'gutenberg_issued', 'gutenberg_type',
#        'identifiers', 'jmdate', 'subjects', 'language_note', 'production_note',
#        'publication_date', 'publication_note', 'publisher', 'rights',
#        'rights_url', 'series_note', 'summary', 'tableOfContents',
#        'titlepage_image', 'url', 'wikipedia', 'filename', 'releaseDate',
#        'wp_publication_date', 'wp_subjects', 'wp_info', 'wp_literary_genres',
#        'gr_rating', 'gr_numReviews', 'gr_pubDate', 'gr_id', 'gr_info',
#        'gr_author_id', 'gr_image_url', 'gr_small_image_url', 'am_title',
#        'am_author', 'am_cat', 'am_cat_ancestors', 'am_genre',
#        'am_editorial_reviews', 'am_sales_rank', 'am_isbn'],
#       dtype='object')

# %%
meta = getMeta('2374.0')

# %%
meta['publication_date'], meta['gr_pubDate'], meta['authoryearofbirth'], meta['wp_publication_date']
# Out:
# (0
#  Name: publication_date, dtype: object,
#  0    1880--
#  Name: gr_pubDate, dtype: object,
#  0    1836
#  Name: authoryearofbirth, dtype: object,
#  0
#  Name: wp_publication_date, dtype: object)

# %%
summaryData = {}
for line in decodedLines: 
    bookId = list(line.keys())[0]
    #counts = line[bookId]['colorCounts']
    summaryData[bookId] = line[bookId]['totalNColors'] / line[bookId]['length']

# %%
summaryDf = pd.DataFrame(summaryData, index=['score']).T

# %%
def guessDate(bookId): 
    meta = getMeta(bookId)
    possibleDates = [meta[key] for key in ['gr_pubDate', 'wp_publication_date', 'publication_date']]
    processedDates = [processDate(date) for date in possibleDates]
    if processedDates == []: 
        return False
    return max(processedDates)

def processDate(year):
    try:
        year = year[0]
    except IndexError: 
        return False
    if len(year) < 4: 
        return False 
    year = int(year[:4])
    if year > 1800 and year < 2020: 
        return year
    else: 
        return False

# %%
summaryDf['bookId'] = summaryDf.index

# %%
guessDate("3622.0")
# Out:
# 1880

# %%
summaryDf['date'] = summaryDf['bookId'].apply(guessDate)

# %%
summaryDf
# Out:
#             score   bookId  date
# 2374.0   0.001261   2374.0  1880
# 2864.0   0.000979   2864.0  1880
# 3622.0   0.000287   3622.0  1880
# 3633.0   0.000778   3633.0  1880
# 6036.0   0.001249   6036.0  1880
# ...           ...      ...   ...
# 45636.0  0.000905  45636.0  1925
# 26785.0  0.002566  26785.0  1925
# 17091.0  0.000381  17091.0  1927
# 748.0    0.001557    748.0  1928
# 16376.0  0.001649  16376.0  1928
#
# [1206 rows x 3 columns]

# %%
summaryDf.index = summaryDf['date']

# %%
summaryDf[summaryDf['date'] < 1920]['score'].plot()

# %%
avgScores = summaryDf.groupby(summaryDf.index).mean()['score']

# %%
avgScores[avgScores.index < 1930].plot()

# %%
avgScores[avgScores.index < 1930].rolling(5).mean().plot()

# %%
def getDOB(bookId): 
    meta = getMeta(bookId)
    return meta['authoryearofbirth']

# %%
summaryDf['dob'] = summaryDf['bookId'].apply(getDOB)

# %%
def maybeInt(yearStr): 
    if yearStr == '': 
        return None
    else: 
        return int(yearStr)

# %%
summaryDf['intDOB'] = summaryDf['dob'].apply(maybeInt)

# %%
byDOB = summaryDf.groupby(summaryDf['intDOB']).mean()

# %%
ax = byDOB[byDOB.index > 1820]['score'].plot(figsize=(12,6))
byDOB[byDOB.index > 1820]['score'].rolling(5).mean().plot(ax=ax, figsize=(12,6))

# %%
byDOB[byDOB.index > 1820]['score'].rolling(5).mean().plot(figsize=(12,6))
