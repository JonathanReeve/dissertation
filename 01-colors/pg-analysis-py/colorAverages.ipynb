# %%
from glob import glob
import json
import pandas as pd
import cufflinks as cf
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import statsmodels
import sqlite3
from collections import Counter
from matplotlib import pyplot as plt

# %%
jsonFiles = [open(f).read() for f in glob('results-json/*')]

# %%
parsedFiles = [json.loads(jsonFile) for jsonFile in jsonFiles]

# %%
len(parsedFiles[0])
# Out:
# 37

# %%
allData = {}
for fileData in parsedFiles:
    for bookData in fileData: 
        colorData = {itemDict['colorWord']: itemDict['nMatches'] for itemDict in bookData[0]['statsList']}
        allData[bookData[0]['textName']] = colorData

# %%
df = pd.DataFrame(allData)

# %%
df = df.T.sort_index()

# %%
df
# Out:
#                                                        black  midnight  \
# 1880-DoraThorne-2374                                0.000012       NaN
# 1880-GreeneFerneFarm-37046                          0.000102       NaN
# 1880-JezebelsDaughter-3633                          0.000021  0.000002
# 1880-RoundAboutaGreatEstate-20528                   0.000114  0.000005
# 1880-ShakespearesInsomniaandtheCausesThereof-11990       NaN       NaN
# ...                                                      ...       ...
# 1925-TheVerseBookofaHomelyWoman-3477                0.000017       NaN
# 192511-ModernBritishPoetry-26785                    0.000082  0.000023
# 192711-OliverCromwellAPlay-17091                         NaN  0.000012
# 1928-BrowningsShorterPoems-16376                    0.000067  0.000010
# 1928-TheBrotherofDaphne-748                         0.000049  0.000005
#
#                                                         dark     blood  \
# 1880-DoraThorne-2374                                0.000182  0.000005
# 1880-GreeneFerneFarm-37046                          0.000128  0.000053
# 1880-JezebelsDaughter-3633                          0.000030  0.000012
# 1880-RoundAboutaGreatEstate-20528                   0.000041  0.000010
# 1880-ShakespearesInsomniaandtheCausesThereof-11990  0.000020  0.000020
# ...                                                      ...       ...
# 1925-TheVerseBookofaHomelyWoman-3477                0.000052       NaN
# 192511-ModernBritishPoetry-26785                    0.000085  0.000056
# 192711-OliverCromwellAPlay-17091                    0.000012  0.000058
# 1928-BrowningsShorterPoems-16376                    0.000030  0.000070
# 1928-TheBrotherofDaphne-748                         0.000104  0.000022
#
#                                                        brown   crimson  \
# 1880-DoraThorne-2374                                     NaN  0.000023
# 1880-GreeneFerneFarm-37046                          0.000071  0.000031
# 1880-JezebelsDaughter-3633                          0.000005       NaN
# 1880-RoundAboutaGreatEstate-20528                   0.000077  0.000005
# 1880-ShakespearesInsomniaandtheCausesThereof-11990       NaN       NaN
# ...                                                      ...       ...
# 1925-TheVerseBookofaHomelyWoman-3477                0.000069  0.000017
# 192511-ModernBritishPoetry-26785                    0.000036  0.000023
# 192711-OliverCromwellAPlay-17091                         NaN       NaN
# 1928-BrowningsShorterPoems-16376                    0.000020       NaN
# 1928-TheBrotherofDaphne-748                         0.000075       NaN
#
#                                                         dusk    violet  \
# 1880-DoraThorne-2374                                     NaN  0.000007
# 1880-GreeneFerneFarm-37046                          0.000009  0.000009
# 1880-JezebelsDaughter-3633                               NaN  0.000002
# 1880-RoundAboutaGreatEstate-20528                   0.000005  0.000005
# 1880-ShakespearesInsomniaandtheCausesThereof-11990       NaN  0.000020
# ...                                                      ...       ...
# 1925-TheVerseBookofaHomelyWoman-3477                0.000017  0.000034
# 192511-ModernBritishPoetry-26785                    0.000013  0.000007
# 192711-OliverCromwellAPlay-17091                         NaN       NaN
# 1928-BrowningsShorterPoems-16376                    0.000007       NaN
# 1928-TheBrotherofDaphne-748                         0.000002       NaN
#
#                                                          red     earth  ...  \
# 1880-DoraThorne-2374                                0.000004  0.000032  ...
# 1880-GreeneFerneFarm-37046                          0.000084  0.000093  ...
# 1880-JezebelsDaughter-3633                          0.000018  0.000004  ...
# 1880-RoundAboutaGreatEstate-20528                   0.000067  0.000026  ...
# 1880-ShakespearesInsomniaandtheCausesThereof-11990       NaN  0.000039  ...
# ...                                                      ...       ...  ...
# 1925-TheVerseBookofaHomelyWoman-3477                0.000052  0.000103  ...
# 192511-ModernBritishPoetry-26785                    0.000088  0.000170  ...
# 192711-OliverCromwellAPlay-17091                    0.000012  0.000023  ...
# 1928-BrowningsShorterPoems-16376                    0.000077  0.000157  ...
# 1928-TheBrotherofDaphne-748                         0.000083  0.000036  ...
#
#                                                     terracotta  \
# 1880-DoraThorne-2374                                       NaN
# 1880-GreeneFerneFarm-37046                                 NaN
# 1880-JezebelsDaughter-3633                                 NaN
# 1880-RoundAboutaGreatEstate-20528                          NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990         NaN
# ...                                                        ...
# 1925-TheVerseBookofaHomelyWoman-3477                       NaN
# 192511-ModernBritishPoetry-26785                           NaN
# 192711-OliverCromwellAPlay-17091                           NaN
# 1928-BrowningsShorterPoems-16376                           NaN
# 1928-TheBrotherofDaphne-748                                NaN
#
#                                                     light lavender  hot green  \
# 1880-DoraThorne-2374                                           NaN        NaN
# 1880-GreeneFerneFarm-37046                                     NaN        NaN
# 1880-JezebelsDaughter-3633                                     NaN        NaN
# 1880-RoundAboutaGreatEstate-20528                              NaN        NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990             NaN        NaN
# ...                                                            ...        ...
# 1925-TheVerseBookofaHomelyWoman-3477                           NaN        NaN
# 192511-ModernBritishPoetry-26785                               NaN   0.000003
# 192711-OliverCromwellAPlay-17091                               NaN        NaN
# 1928-BrowningsShorterPoems-16376                               NaN        NaN
# 1928-TheBrotherofDaphne-748                                    NaN        NaN
#
#                                                     warm pink  pale magenta  \
# 1880-DoraThorne-2374                                      NaN           NaN
# 1880-GreeneFerneFarm-37046                                NaN           NaN
# 1880-JezebelsDaughter-3633                                NaN           NaN
# 1880-RoundAboutaGreatEstate-20528                         NaN           NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990        NaN           NaN
# ...                                                       ...           ...
# 1925-TheVerseBookofaHomelyWoman-3477                      NaN           NaN
# 192511-ModernBritishPoetry-26785                          NaN           NaN
# 192711-OliverCromwellAPlay-17091                          NaN           NaN
# 1928-BrowningsShorterPoems-16376                          NaN           NaN
# 1928-TheBrotherofDaphne-748                          0.000002           NaN
#
#                                                     violet pink  \
# 1880-DoraThorne-2374                                        NaN
# 1880-GreeneFerneFarm-37046                                  NaN
# 1880-JezebelsDaughter-3633                                  NaN
# 1880-RoundAboutaGreatEstate-20528                           NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990          NaN
# ...                                                         ...
# 1925-TheVerseBookofaHomelyWoman-3477                        NaN
# 192511-ModernBritishPoetry-26785                            NaN
# 192711-OliverCromwellAPlay-17091                            NaN
# 1928-BrowningsShorterPoems-16376                            NaN
# 1928-TheBrotherofDaphne-748                                 NaN
#
#                                                     brownish purple  \
# 1880-DoraThorne-2374                                            NaN
# 1880-GreeneFerneFarm-37046                                      NaN
# 1880-JezebelsDaughter-3633                                      NaN
# 1880-RoundAboutaGreatEstate-20528                               NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990              NaN
# ...                                                             ...
# 1925-TheVerseBookofaHomelyWoman-3477                            NaN
# 192511-ModernBritishPoetry-26785                                NaN
# 192711-OliverCromwellAPlay-17091                                NaN
# 1928-BrowningsShorterPoems-16376                                NaN
# 1928-TheBrotherofDaphne-748                                     NaN
#
#                                                     bluey green  algae  \
# 1880-DoraThorne-2374                                        NaN    NaN
# 1880-GreeneFerneFarm-37046                                  NaN    NaN
# 1880-JezebelsDaughter-3633                                  NaN    NaN
# 1880-RoundAboutaGreatEstate-20528                           NaN    NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990          NaN    NaN
# ...                                                         ...    ...
# 1925-TheVerseBookofaHomelyWoman-3477                        NaN    NaN
# 192511-ModernBritishPoetry-26785                            NaN    NaN
# 192711-OliverCromwellAPlay-17091                            NaN    NaN
# 1928-BrowningsShorterPoems-16376                            NaN    NaN
# 1928-TheBrotherofDaphne-748                                 NaN    NaN
#
#                                                     macaroni and cheese
# 1880-DoraThorne-2374                                                NaN
# 1880-GreeneFerneFarm-37046                                          NaN
# 1880-JezebelsDaughter-3633                                          NaN
# 1880-RoundAboutaGreatEstate-20528                                   NaN
# 1880-ShakespearesInsomniaandtheCausesThereof-11990                  NaN
# ...                                                                 ...
# 1925-TheVerseBookofaHomelyWoman-3477                                NaN
# 192511-ModernBritishPoetry-26785                                    NaN
# 192711-OliverCromwellAPlay-17091                                    NaN
# 1928-BrowningsShorterPoems-16376                                    NaN
# 1928-TheBrotherofDaphne-748                                         NaN
#
# [796 rows x 449 columns]

# %%
xkcdMap = json.load(open('../data/maps/xkcd/rgb.json'))

# %%
xkcdMap['black']
# Out:
# '#000000'

# %%
def combineHexes(colorDict):
    """
    Proportionally mix hex colors from dict like {"ffffff": 1.0, "0000ff": 0.5 ... }
    """
    colors = sorted(colorDict.items())
    weights = sum(colorDict.values())
    if weights == 0:
        return
    red = int(sum([int(k[:2], 16)*v for k, v in colors])/weights)
    green = int(sum([int(k[2:4], 16)*v for k, v in colors])/weights)
    blue = int(sum([int(k[4:6], 16)*v for k, v in colors])/weights)
    zpad = lambda x: x if len(x)==2 else '0' + x
    return zpad(hex(red)[2:]) + zpad(hex(green)[2:]) + zpad(hex(blue)[2:])

# %%
for i, row in df.iterrows(): 
    data = row[row.notna()].to_dict()
    hexes = {}
    for color, prop in data.items(): 
        colorHex = xkcdMap.get(color)
        if colorHex is None: 
            continue
        hexes[colorHex[1:]] = prop
    avg = combineHexes(hexes)
    df.loc[i, 'avg'] = avg

# %%
df['avg']
# Out:
# 1880-DoraThorne-2374                                  99987d
# 1880-GreeneFerneFarm-37046                            8b855f
# 1880-JezebelsDaughter-3633                            9d6c65
# 1880-RoundAboutaGreatEstate-20528                     9d9a60
# 1880-ShakespearesInsomniaandtheCausesThereof-11990    a48a42
#                                                        ...
# 1925-TheVerseBookofaHomelyWoman-3477                  8f7e68
# 192511-ModernBritishPoetry-26785                      8b7f69
# 192711-OliverCromwellAPlay-17091                      7f6c4f
# 1928-BrowningsShorterPoems-16376                      8c7259
# 1928-TheBrotherofDaphne-748                           8a5560
# Name: avg, Length: 796, dtype: object

# %%
df['avg'].to_json('averages.json')

# %%
df['pgId'] = [fn[-1] for fn in df.index.str.split('-')]

# %% [markdown]
# # Metadata

# %%
conn = sqlite3.connect('/home/jon/Corpora/pg-text-7.db')

# %%
c = conn.cursor()

# %%
def getAuthor(textName):
    textId = textName.split('-')[-1]
    c.execute('select author from meta where id=?', [str(float(textId))])
    return c.fetchone()[0]

# %%
for i, row in df.iterrows(): 
    bookId = i.split('-')[-1]
    author = getAuthor(bookId)
    df.loc[i, 'author'] = author

# %%
dfAuthor = df.groupby('author').mean()

# %%
for i, row in dfAuthor.iterrows(): 
    data = row[row.notna()].to_dict()
    hexes = {}
    for color, prop in data.items(): 
        colorHex = xkcdMap.get(color)
        if colorHex is None: 
            continue
        hexes[colorHex[1:]] = prop
    avg = combineHexes(hexes)
    dfAuthor.loc[i, 'avg'] = avg

# %%
dfAuthor['avg']
# Out:
# author
#                         82765e
# Alexander, Mrs.         8c7d6b
# Allan, Luke             5f6675
# Allen, Grant            967965
# Anonymous               ba7575
#                          ...
# Woolf, Virginia         888369
# Wren, Jenny             7c8361
# Yates, Dornford         8d4f5e
# Young, Francis Brett    8f896f
# Zangwill, Israel        8e7761
# Name: avg, Length: 262, dtype: object

# %%
dfAuthor['avg'].to_json('averages-author.json')

# %%
dfAuthor
# Out:
#                          black  midnight      dark     blood     brown  \
# author
#                       0.000917  0.000222  0.000934  0.000512  0.000231
# Alexander, Mrs.       0.000044  0.000001  0.000045  0.000007  0.000014
# Allan, Luke           0.000017  0.000012  0.000061  0.000087  0.000014
# Allen, Grant          0.000559  0.000008  0.000264  0.000471  0.000190
# Anonymous             0.000000  0.000000  0.000017  0.000011  0.000000
# ...                        ...       ...       ...       ...       ...
# Woolf, Virginia       0.000348  0.000037  0.000293  0.000059  0.000166
# Wren, Jenny           0.000045  0.000000  0.000007  0.000000  0.000007
# Yates, Dornford       0.000074  0.000007  0.000132  0.000040  0.000103
# Young, Francis Brett  0.000194  0.000014  0.000346  0.000083  0.000097
# Zangwill, Israel      0.000353  0.000043  0.000182  0.000235  0.000109
#
#                        crimson      dusk    violet       red     earth  ...  \
# author                                                                  ...
#                       0.000104  0.000116  0.000033  0.000815  0.000807  ...
# Alexander, Mrs.       0.000004  0.000003  0.000000  0.000022  0.000008  ...
# Allan, Luke           0.000003  0.000003  0.000000  0.000014  0.000029  ...
# Allen, Grant          0.000097  0.000008  0.000000  0.000494  0.000700  ...
# Anonymous             0.000006  0.000000  0.000000  0.000006  0.000000  ...
# ...                        ...       ...       ...       ...       ...  ...
# Woolf, Virginia       0.000043  0.000050  0.000041  0.000450  0.000253  ...
# Wren, Jenny           0.000007  0.000000  0.000000  0.000015  0.000037  ...
# Yates, Dornford       0.000000  0.000014  0.000002  0.000120  0.000068  ...
# Young, Francis Brett  0.000014  0.000028  0.000000  0.000138  0.000138  ...
# Zangwill, Israel      0.000025  0.000025  0.000005  0.000271  0.000176  ...
#
#                       terracotta  light lavender  hot green  warm pink  \
# author
#                              0.0             0.0   0.000003   0.000000
# Alexander, Mrs.              0.0             0.0   0.000000   0.000000
# Allan, Luke                  0.0             0.0   0.000000   0.000000
# Allen, Grant                 0.0             0.0   0.000000   0.000000
# Anonymous                    0.0             0.0   0.000000   0.000000
# ...                          ...             ...        ...        ...
# Woolf, Virginia              0.0             0.0   0.000000   0.000000
# Wren, Jenny                  0.0             0.0   0.000000   0.000000
# Yates, Dornford              0.0             0.0   0.000000   0.000002
# Young, Francis Brett         0.0             0.0   0.000000   0.000000
# Zangwill, Israel             0.0             0.0   0.000000   0.000000
#
#                       pale magenta  violet pink  brownish purple  bluey green  \
# author
#                                0.0          0.0              0.0          0.0
# Alexander, Mrs.                0.0          0.0              0.0          0.0
# Allan, Luke                    0.0          0.0              0.0          0.0
# Allen, Grant                   0.0          0.0              0.0          0.0
# Anonymous                      0.0          0.0              0.0          0.0
# ...                            ...          ...              ...          ...
# Woolf, Virginia                0.0          0.0              0.0          0.0
# Wren, Jenny                    0.0          0.0              0.0          0.0
# Yates, Dornford                0.0          0.0              0.0          0.0
# Young, Francis Brett           0.0          0.0              0.0          0.0
# Zangwill, Israel               0.0          0.0              0.0          0.0
#
#                       algae  macaroni and cheese
# author
#                         0.0             0.000000
# Alexander, Mrs.         0.0             0.000000
# Allan, Luke             0.0             0.000000
# Allen, Grant            0.0             0.000002
# Anonymous               0.0             0.000000
# ...                     ...                  ...
# Woolf, Virginia         0.0             0.000000
# Wren, Jenny             0.0             0.000000
# Yates, Dornford         0.0             0.000000
# Young, Francis Brett    0.0             0.000000
# Zangwill, Israel        0.0             0.000000
#
# [262 rows x 449 columns]

# %%
dfAuthor.sum(axis=1).sort_values(ascending=False).head(30)
# Out:
# author
# Custance, Olive                                          0.005390
# De la Mare, Walter                                       0.004363
# Young, Francis Brett                                     0.004233
# Colum, Padraic                                           0.003542
# Thackeray, William Makepeace                             0.003266
# Blind, Mathilde                                          0.003251
# Carman, Bliss                                            0.003229
# Huxley, Aldous                                           0.003174
# Noyes, Alfred                                            0.003120
# Dunsany, Lord                                            0.003108
# Masefield, John                                          0.003095
# Wilde, Oscar                                             0.003007
# Graves, Robert                                           0.002985
# Sackville-West, Vita (Victoria Mary)                     0.002852
# Burke, Thomas                                            0.002830
# Marie, Queen, consort of Ferdinand I, King of Romania    0.002782
# Shelley, Mary Wollstonecraft                             0.002721
# Swinburne, Algernon Charles                              0.002667
# Flecker, James Elroy                                     0.002597
# Palgrave, Francis Turner                                 0.002543
#                                                          0.002520
# Russell, George William                                  0.002501
# Joyce, James                                             0.002402
# Brooke, Rupert                                           0.002396
# Hood, Thomas                                             0.002382
# Jefferies, Richard                                       0.002309
# Byrne, Donn                                              0.002284
# Benson, Stella                                           0.002255
# Mansfield, Katherine                                     0.002245
# Ashford, Daisy                                           0.002228
# dtype: float64

# %%
dfAuthor[['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'violet', 'black', 'white', 'grey', 'brown']].sum().sort_values(ascending=False)
# Out:
# white     0.072279
# black     0.050090
# red       0.039819
# green     0.030233
# blue      0.029297
# grey      0.020969
# brown     0.018961
# yellow    0.014917
# purple    0.005473
# violet    0.003151
# orange    0.002689
# dtype: float64

# %%
def commonColorsByAuthor(author): 
    threshold = dfAuthor.loc[author].sum() * 0.03
    return dfAuthor.loc[author][dfAuthor.loc[author] > threshold]

# %%
dfWoolf = commonColorsByAuthor('Woolf, Virginia')
dfWoolf.index
# Out:
# Index(['black', 'dark', 'red', 'earth', 'sky', 'yellow', 'white', 'blue',
#        'rose', 'sea', 'green', 'tea'],
#       dtype='object')

# %%
dfAuthor.loc['Wilde, Oscar'].sum()
# Out:
# 0.019771713353581768

# %%
commonColorsByAuthor('Woolf, Virginia')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-cbbb51be9afd> in <module>
# ----> 1 commonColorsByAuthor('Woolf, Virginia')
#
# <ipython-input-130-ca6bde9b7bd8> in commonColorsByAuthor(author)
#       1 def commonColorsByAuthor(author):
#       2     threshold = dfAuthor.loc[author].sum() * 0.03
# ----> 3     dfAuthor.loc[author][dfAuthor.loc[author] > threshold].plot(kind='pie', normalize=True, color_map=xkcdMap)
#
# /nix/store/42gajlmxadiwvadjx49q9vpfqihrylpx-python3-3.8.6-env/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /nix/store/42gajlmxadiwvadjx49q9vpfqihrylpx-python3-3.8.6-env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /nix/store/42gajlmxadiwvadjx49q9vpfqihrylpx-python3-3.8.6-env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# /nix/store/42gajlmxadiwvadjx49q9vpfqihrylpx-python3-3.8.6-env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1545             else:
#    1546                 blabels = None
# -> 1547             results = ax.pie(y, labels=blabels, **kwds)
#    1548
#    1549             if kwds.get("autopct", None) is not None:
#
# /nix/store/42gajlmxadiwvadjx49q9vpfqihrylpx-python3-3.8.6-env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: pie() got an unexpected keyword argument 'color_map'

# %%
def plotColorsAuthor(author): 
    
commonColorsByAuthor('Joyce, James')

# %%
commonColorsByAuthor('Wilde, Oscar')

# %%
commonColorsByAuthor('Thackeray, William Makepeace')

# %%
commonColorsByAuthor('Shakespeare, William')

# %%
commonColorsByAuthor('Carroll, Lewis')
