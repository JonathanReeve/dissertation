# %%
import spacy
from collections import Counter
import re

# %%
nlp = spacy.load('en_core_web_md')

# %%
nlp.max_length=6000000

# %%
nutallRaw = open('../data/dict/pg12342.txt').read()

# %%
baseColors = ['black', 'grey', 'brown', 'white', 'red', 'orange', 'yellow', 'green', 'blue']

# %% [markdown]
# # Dictionaries
#
# ## The Nutall Encyclopedia
#
# Title: The Nuttall Encyclopaedia
#        Being a Concise and Comprehensive Dictionary of General Knowledge
#
# Release Date: May 14, 2004 [EBook #12342]

# %%
def processNutall(text): 
    paras = text.split('\n\n')
    definitions = {}
    for para in paras: 
        para = para.replace('\n', ' ')
        result = re.match('([A-Z `,.]{2,}), (.*)', para) 
        if result is not None:
            word = result.group(1).strip()
            definition = result.group(2)
            definitions[word] = definition
    return definitions

# %%
nutall = processNutall(nutallRaw)

# %%
def vectorizeDict(nutallDict): 
    """ 
    Given a dictionary of word: definition, 
    score words for color content by giving a point whenever a color word
    appears in a word's definition. 
    """ 
    colorWords = {}
    for word, definition in nutallDict.items(): 
        #print(word, definition)
        defDoc = nlp(definition)
        for w in defDoc: 
            wStr = str(w.lemma_)
            if wStr in baseColors: 
                #print(wStr)
                if wStr in colorWords: 
                    colorWords[wStr].append(word)
                else: 
                    colorWords[wStr] = [word]
    return colorWords

# %%
vectorizeDict(nutall)
# Out:
# {'green': ['AFFRE',
#   'BYRON, GEORGE GORDON, SIXTH LORD',
#   'CHLOROPHYLL',
#   'CHLOROSIS',
#   'DESMOULINS, CAMILLE',
#   'DESMOULINS, CAMILLE',
#   'DESMOULINS, CAMILLE',
#   'DESMOULINS, CAMILLE',
#   'EMERALD',
#   'EMIR',
#   'FERGUSSON, ROBERT',
#   'GARNET',
#   'JACKAROO',
#   'MAKRIZI',
#   'RIBBONISM',
#   'SILAGE',
#   'SILAGE',
#   'STARS, THE',
#   'THALLIUM'],
#  'red': ['ALBINOS',
#   'AMERICAN INDIANS',
#   'BART',
#   'BERRYER, PIERRE ANTOINE',
#   'CHICA',
#   'CHROMATICS',
#   'ECZEMA',
#   'ELLORA',
#   'ERYTHEMA',
#   'FARINATA',
#   'GARDE NATIONALE',
#   'GARNET',
#   'GERYON',
#   'HOGG, JAMES',
#   'KRAKATAO',
#   'LACHRYMA CHRISTI',
#   'LEVELLERS',
#   'MAURY',
#   'RED SEA',
#   'ROBESPIERRE, MAXIMILIEN',
#   'ROSES, WARS OF THE',
#   'RUBRICS',
#   'RUBRICS',
#   'SOUTHEY, ROBERT',
#   'STARS, THE',
#   'TALUS',
#   'TEMPLARS',
#   'TRICOLOUR',
#   'WARS OF THE ROSES',
#   'WOOLSACK'],
#  'white': ['ALBION',
#   'ALBUMEN',
#   'ANDREW, ST.',
#   'ANTIMONY',
#   'A`PIS',
#   'AURO`RA',
#   'BERNARD, ST.',
#   'CAGNOLA, LUIGI, MARQUIS OF',
#   'CAMERA LUCIDA',
#   'CHITIN',
#   'DRUMMOND LIGHT',
#   'DRYDEN, JOHN',
#   'ELECTRIC LIGHT',
#   'ELEPHANT',
#   'ESKIMO DOG',
#   'ETHNOLOGY',
#   'EUROPA',
#   'FI`DES',
#   'GARDE NATIONALE',
#   'GLACIER',
#   'GRIQUALAND, WEST AND EAST',
#   'GRIQUALAND, WEST AND EAST',
#   'HISSAR',
#   'HUBERT, ST.',
#   'ICE BLINK',
#   'INDIA',
#   'JACK',
#   'JADE',
#   'JAINAS',
#   'KAFFIRS',
#   'KAOLIN',
#   'LEANING TOWER',
#   'LEGION OF HONOUR',
#   'MEGARIS',
#   'NEGATIVE',
#   'ONYX',
#   'ONYX',
#   'PAPY`RUS',
#   'PENTELICUS',
#   'PERSIUS',
#   'PETER, THE APOSTLE',
#   'PORTLAND VASE',
#   'PRISMATIC COLOURS',
#   'QUADROON',
#   'ROSES, WARS OF THE',
#   'SALICYLIC ACID',
#   'SPERMACETI',
#   'STARS, THE',
#   'SUN, THE',
#   'TEMPLARS',
#   'TOGA',
#   'TRICOLOUR',
#   'UNION JACK',
#   'VANADIUM',
#   'WARS OF THE ROSES',
#   'WHITE HORSE',
#   'WHITE HOUSE',
#   'WHITE LADY',
#   'WHITEBOYS',
#   'YTTRIUM',
#   'YUMBOES'],
#  'yellow': ['AMBER',
#   'BELL, PETER',
#   'CHLORINE',
#   'CHROMATICS',
#   'ETHNOLOGY',
#   'GARNET',
#   'GIRARD, STEPHEN',
#   'IMPETIGO',
#   'OPAL',
#   'ORMOLU',
#   'QUARANTINE',
#   'QUERCITRON',
#   'SHAMROCK'],
#  'black': ['AMERICAN INDIANS',
#   'AMERICAN INDIANS',
#   'A`PIS',
#   'ARTHUR SEAT',
#   'ASPHALT',
#   'ASPHALT',
#   'BLACK LANDS',
#   'BLACK ROD, GENTLEMAN USHER OF',
#   'BRADWARDIN, THOMAS',
#   'CAABA',
#   'CAPE HORN',
#   'COOKE, T. P.',
#   'DANTON, GEORGES JACQUES',
#   'EDWARD III.',
#   'EMERY',
#   'ERSKINE, RALPH',
#   'ESKIMO DOG',
#   'ETHIOPIA',
#   'FAUST',
#   'FLYING DUTCHMAN',
#   'GARNET',
#   'HORNBOOK',
#   'HUNS, THE',
#   'JERROLD, DOUGLAS',
#   'JET',
#   'JULIAN THE APOSTATE',
#   'MALAYS',
#   'MELVILLE',
#   'MEZZOTINT',
#   'NEGROES',
#   'ONYX',
#   'PESSIMISM',
#   'REDGAUNTLET',
#   'SERAPHIM',
#   'SILHOUETTE',
#   'SUMNER, CHARLES',
#   'THOR',
#   'VENUS',
#   'ZIRCONIUM'],
#  'blue': ['ARTHUR SEAT',
#   'CANOPUS',
#   'CHROMATICS',
#   'DICKENS, CHARLES',
#   'DIPPEL, JOHANN KONRAD',
#   'EMERY',
#   'EPHOD',
#   'GARDE NATIONALE',
#   'GARTER, THE MOST NOBLE ORDER OF THE',
#   'GENEVA, LAKE OF',
#   'HOGG, JAMES',
#   'INDIA',
#   'KINGSTON',
#   'LITERATURE',
#   'NERBUDDA',
#   'OPAL',
#   'PORTLAND VASE',
#   'SAPPHIRE',
#   'STARS, THE',
#   'TRICOLOUR',
#   'TRICOLOUR',
#   'WETTER, LAKE',
#   'WILSON, JOHN'],
#  'orange': ['AZORES',
#   'CHICA',
#   'CHIOS',
#   'GOZZI, COUNT CARLO',
#   'SAHARA',
#   'SHITTIM WOOD',
#   'STARS, THE'],
#  'brown': ['AZ`TECS',
#   'BROWNING, ROBERT',
#   'CAIRNGORM',
#   'CARIBS',
#   'CATHARINE I.',
#   'HOME, DANIEL DUNGLAS',
#   'MALAYS',
#   'ONYX',
#   'PAPY`RUS',
#   'SHITTIM WOOD'],
#  'grey': ['CAZOTTE',
#   'CHINCHILLA',
#   'DUMOURIEZ',
#   'ESKIMO DOG',
#   'GREY FRIARS',
#   'HOGG, JAMES',
#   'JADE',
#   'WOLSEY, THOMAS']}

# %%
texts = ['../data/text/lighthouse.md', '../data/text/pride.txt', '../data/text/dalloway.txt']

# %%
# %%timeit -n1 -r1
n = 10
colorNeighbors = {}
posList = ['NN', 'JJ', 'JJR', 'JJR', 'NNS']

for text in texts: 
    rawText = open(text).read()
    if len(rawText) > 4000000: 
        textParts = [rawText[i:i + n] for i in range(0, len(rawText), n)]
    else: 
        textParts = [rawText]
    for textPart in textParts:
        textDoc = nlp(textPart)
        for w in textDoc: 
            if str(w.lemma_) in baseColors: 
                neighbors = []
                for wordIndex in range(1, n+1):
                    score = 1 / wordIndex 
                    try: 
                        backWord = textDoc[w.i - wordIndex]
                        backWordStr = str(backWord.lemma_)
                        if backWord.tag_ in posList and backWord.is_alpha:
                            neighbors.append((backWordStr, score))
                        frontWord = textDoc[w.i + wordIndex]
                        frontWordStr = str(frontWord.lemma_)
                        if frontWord.tag_ in posList and frontWord.is_alpha:
                            neighbors.append((frontWordStr, score))
                    except IndexError:
                        continue
            else:
                continue
            if len(neighbors) > 0:
                wStr = str(w.lemma_)
                if wStr in colorNeighbors: 
                    colorNeighbors[wStr] += neighbors
                else: 
                    colorNeighbors[wStr] = neighbors
# Out:
# 16.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
colorNeighborsSums = {}
for color, scoreList in colorNeighbors.items():
    combinedScores = {}
    for wordAndScore in scoreList:
        word, score = wordAndScore
        if word in combinedScores:
            combinedScores[word] += score
        else: 
            combinedScores[word] = score
    colorNeighborsSums[color] = combinedScores

# %%
colorNeighborsSumsSorted = {color: {k: v for k, v in sorted(stats.items(), key=lambda item: item[1], reverse=True)} for color, stats in colorNeighborsSums.items()}
colorNeighborsSumsSorted
# Out:
# {'blue': {'eye': 6.2,
#   'hydrangea': 2.725,
#   'light': 2.4166666666666665,
#   'smoke': 2.333333333333333,
#   'green': 2.2916666666666665,
#   'bay': 1.4777777777777779,
#   'black': 1.2833333333333332,
#   'little': 1.225,
#   'evening': 1.211111111111111,
#   'high': 1.2,
#   'bright': 1.1666666666666667,
#   'dark': 1.1,
#   'grey': 1.0833333333333333,
#   'bar': 1.0,
#   'censer': 1.0,
#   'coat': 1.0,
#   'envelope': 1.0,
#   'eyed': 1.0,
#   'fierce': 1.0,
#   'frail': 1.0,
#   'haze': 1.0,
#   'morning': 1.0,
#   'paint': 1.0,
#   'pale': 1.0,
#   'petal': 1.0,
#   'ribbon': 1.0,
#   'shape': 1.0,
#   'sofa': 1.0,
#   'water': 0.8666666666666667,
#   'distance': 0.85,
#   'red': 0.8333333333333333,
#   'wave': 0.7261904761904762,
#   'sky': 0.7083333333333333,
#   'white': 0.6761904761904762,
#   'cloud': 0.6666666666666666,
#   'air': 0.6428571428571428,
#   'clear': 0.6428571428571428,
#   'leave': 0.6416666666666666,
#   'window': 0.6166666666666667,
#   'moment': 0.6,
#   'plume': 0.6,
#   'line': 0.5833333333333333,
#   'side': 0.5333333333333333,
#   'day': 0.5111111111111111,
#   'blue': 0.5079365079365079,
#   'brown': 0.5,
#   'cave': 0.5,
#   'circular': 0.5,
#   'cloth': 0.5,
#   'deep': 0.5,
#   'flash': 0.5,
#   'greek': 0.5,
#   'haired': 0.5,
#   'mound': 0.5,
#   'pearl': 0.5,
#   'pink': 0.5,
#   'silver': 0.5,
#   'tuft': 0.5,
#   'yellow': 0.5,
#   'something': 0.4583333333333333,
#   'purple': 0.43333333333333335,
#   'colour': 0.3666666666666667,
#   'horse': 0.3666666666666667,
#   'letter': 0.3666666666666667,
#   'tree': 0.34285714285714286,
#   'ceiling': 0.3333333333333333,
#   'flamingo': 0.3333333333333333,
#   'hair': 0.3333333333333333,
#   'hillock': 0.3333333333333333,
#   'honest': 0.3333333333333333,
#   'much': 0.3333333333333333,
#   'plateful': 0.3333333333333333,
#   'plumage': 0.3333333333333333,
#   'set': 0.3333333333333333,
#   'shore': 0.3333333333333333,
#   'smooth': 0.3333333333333333,
#   'steadfast': 0.3333333333333333,
#   'summer': 0.2857142857142857,
#   'soft': 0.2777777777777778,
#   'bird': 0.26785714285714285,
#   'picture': 0.26666666666666666,
#   'hand': 0.25396825396825395,
#   'candid': 0.25,
#   'change': 0.25,
#   'cry': 0.25,
#   'fair': 0.25,
#   'forehead': 0.25,
#   'great': 0.25,
#   'heart': 0.25,
#   'need': 0.25,
#   'nose': 0.25,
#   'oak': 0.25,
#   'room': 0.25,
#   'sea': 0.25,
#   'straight': 0.25,
#   'stuff': 0.24285714285714285,
#   'long': 0.2361111111111111,
#   'back': 0.2,
#   'branch': 0.2,
#   'coal': 0.2,
#   'cool': 0.2,
#   'cut': 0.2,
#   'daylight': 0.2,
#   'door': 0.2,
#   'effort': 0.2,
#   'frightening': 0.2,
#   'horizon': 0.2,
#   'human': 0.2,
#   'illness': 0.2,
#   'instinctive': 0.2,
#   'mesh': 0.2,
#   'thick': 0.2,
#   'way': 0.2,
#   'apron': 0.16666666666666666,
#   'being': 0.16666666666666666,
#   'bravely': 0.16666666666666666,
#   'deal': 0.16666666666666666,
#   'delphinium': 0.16666666666666666,
#   'half': 0.16666666666666666,
#   'hollow': 0.16666666666666666,
#   'nosed': 0.16666666666666666,
#   'nothing': 0.16666666666666666,
#   'other': 0.16666666666666666,
#   'palette': 0.16666666666666666,
#   'pattern': 0.16666666666666666,
#   'pure': 0.16666666666666666,
#   'sharp': 0.16666666666666666,
#   'splinter': 0.16666666666666666,
#   'vapour': 0.16666666666666666,
#   'brush': 0.14285714285714285,
#   'considerate': 0.14285714285714285,
#   'faint': 0.14285714285714285,
#   'general': 0.14285714285714285,
#   'glass': 0.14285714285714285,
#   'hedge': 0.14285714285714285,
#   'hoary': 0.14285714285714285,
#   'hoop': 0.14285714285714285,
#   'pulse': 0.14285714285714285,
#   'reflection': 0.14285714285714285,
#   'shaded': 0.14285714285714285,
#   'steel': 0.14285714285714285,
#   'sunlight': 0.14285714285714285,
#   'vivacious': 0.14285714285714285,
#   'beech': 0.125,
#   'child': 0.125,
#   'distinguished': 0.125,
#   'early': 0.125,
#   'end': 0.125,
#   'front': 0.125,
#   'goose': 0.125,
#   'habit': 0.125,
#   'invisible': 0.125,
#   'knee': 0.125,
#   'one': 0.125,
#   'parsley': 0.125,
#   'somebody': 0.125,
#   'stubble': 0.125,
#   'thought': 0.125,
#   'upper': 0.125,
#   'alight': 0.1111111111111111,
#   'brasier': 0.1111111111111111,
#   'clean': 0.1111111111111111,
#   'clod': 0.1111111111111111,
#   'contrary': 0.1111111111111111,
#   'cow': 0.1111111111111111,
#   'dress': 0.1111111111111111,
#   'enthusiastic': 0.1111111111111111,
#   'field': 0.1111111111111111,
#   'ice': 0.1111111111111111,
#   'incongruous': 0.1111111111111111,
#   'last': 0.1111111111111111,
#   'legged': 0.1111111111111111,
#   'mind': 0.1111111111111111,
#   'part': 0.1111111111111111,
#   'past': 0.1111111111111111,
#   'sail': 0.1111111111111111,
#   'sharpened': 0.1111111111111111,
#   'superb': 0.1111111111111111,
#   'wall': 0.1111111111111111,
#   'able': 0.1,
#   'attempt': 0.1,
#   'carnation': 0.1,
#   'disappearing': 0.1,
#   'distant': 0.1,
#   'harmony': 0.1,
#   'invitation': 0.1,
#   'leg': 0.1,
#   'length': 0.1,
#   'lovely': 0.1,
#   'many': 0.1,
#   'mass': 0.1,
#   'mountain': 0.1,
#   'old': 0.1,
#   'power': 0.1,
#   'print': 0.1,
#   'screen': 0.1,
#   'severity': 0.1,
#   'space': 0.1,
#   'table': 0.1,
#   'wing': 0.1,
#   'woman': 0.1,
#   'word': 0.1},
#  'red': {'hot': 3.0,
#   'nostril': 3.0,
#   'flower': 2.6666666666666665,
#   'rose': 2.6527777777777777,
#   'yellow': 2.642857142857143,
#   'gold': 2.0,
#   'white': 1.9166666666666665,
#   'poker': 1.9166666666666663,
#   'little': 1.8444444444444443,
#   'lip': 1.5833333333333333,
#   'carnation': 1.5,
#   'bright': 1.1666666666666667,
#   'house': 1.1428571428571428,
#   'fresh': 1.1111111111111112,
#   'something': 1.0,
#   'clump': 1.0,
#   'haired': 1.0,
#   'round': 1.0,
#   'glimmer': 1.0,
#   'geranium': 1.0,
#   'cheek': 1.0,
#   'plush': 1.0,
#   'flat': 1.0,
#   'aster': 1.0,
#   'ink': 1.0,
#   'sturdy': 1.0,
#   'fruit': 1.0,
#   'brick': 1.0,
#   'hairy': 1.0,
#   'chair': 1.0,
#   'huge': 1.0,
#   'letter': 1.0,
#   'sock': 1.0,
#   'cloak': 1.0,
#   'hand': 0.95,
#   'brown': 0.8333333333333333,
#   'blue': 0.8333333333333333,
#   'face': 0.8333333333333333,
#   'brute': 0.8095238095238095,
#   'thick': 0.7,
#   'bowl': 0.7,
#   'woman': 0.6761904761904762,
#   'eye': 0.55,
#   'man': 0.5,
#   'ermine': 0.5,
#   'torch': 0.5,
#   'seat': 0.5,
#   'lean': 0.5,
#   'raucous': 0.5,
#   'brush': 0.5,
#   'energetic': 0.5,
#   'prim': 0.5,
#   'violet': 0.5,
#   'deep': 0.5,
#   'nothing': 0.5,
#   'flame': 0.5,
#   'blood': 0.5,
#   'saucer': 0.5,
#   'grey': 0.4583333333333333,
#   'light': 0.43333333333333335,
#   'horse': 0.43333333333333335,
#   'friendship': 0.375,
#   'black': 0.3611111111111111,
#   'green': 0.35,
#   'hat': 0.35,
#   'basket': 0.3333333333333333,
#   'distance': 0.3333333333333333,
#   'trailing': 0.3333333333333333,
#   'kitchen': 0.3333333333333333,
#   'tall': 0.3333333333333333,
#   'rook': 0.3333333333333333,
#   'orange': 0.3333333333333333,
#   'cow': 0.3333333333333333,
#   'film': 0.3333333333333333,
#   'beauty': 0.3333333333333333,
#   'askew': 0.3333333333333333,
#   'varnish': 0.3333333333333333,
#   'ash': 0.3333333333333333,
#   'friend': 0.3333333333333333,
#   'curtain': 0.3333333333333333,
#   'flesh': 0.3111111111111111,
#   'basin': 0.29166666666666663,
#   'wall': 0.2857142857142857,
#   'old': 0.26785714285714285,
#   'place': 0.26785714285714285,
#   'peat': 0.25,
#   'contentment': 0.25,
#   'hedge': 0.25,
#   'century': 0.25,
#   'soup': 0.25,
#   'shaded': 0.25,
#   'dahlia': 0.25,
#   'shiny': 0.25,
#   'dark': 0.25,
#   'heat': 0.25,
#   'mat': 0.25,
#   'placard': 0.25,
#   'young': 0.24285714285714285,
#   'glass': 0.2361111111111111,
#   'word': 0.225,
#   'paper': 0.2111111111111111,
#   'day': 0.2,
#   'hoop': 0.2,
#   'smooth': 0.2,
#   'profound': 0.2,
#   'brasier': 0.2,
#   'mortal': 0.2,
#   'gaze': 0.2,
#   'fiery': 0.2,
#   'smoke': 0.2,
#   'winey': 0.2,
#   'love': 0.2,
#   'ant': 0.2,
#   'head': 0.2,
#   'field': 0.2,
#   'neck': 0.2,
#   'thrilled': 0.2,
#   'ethereal': 0.2,
#   'subject': 0.2,
#   'undemonstrative': 0.2,
#   'heart': 0.2,
#   'caravan': 0.2,
#   'tray': 0.2,
#   'refrigerator': 0.16666666666666666,
#   'urn': 0.16666666666666666,
#   'gap': 0.16666666666666666,
#   'skin': 0.16666666666666666,
#   'nettle': 0.16666666666666666,
#   'sea': 0.16666666666666666,
#   'smell': 0.16666666666666666,
#   'thin': 0.16666666666666666,
#   'purple': 0.16666666666666666,
#   'glow': 0.16666666666666666,
#   'month': 0.16666666666666666,
#   'wear': 0.16666666666666666,
#   'happy': 0.16666666666666666,
#   'bedroom': 0.16666666666666666,
#   'course': 0.16666666666666666,
#   'full': 0.16666666666666666,
#   'garish': 0.16666666666666666,
#   'secret': 0.16666666666666666,
#   'air': 0.14285714285714285,
#   'clear': 0.14285714285714285,
#   'body': 0.14285714285714285,
#   'visible': 0.14285714285714285,
#   'process': 0.14285714285714285,
#   'leopard': 0.14285714285714285,
#   'branch': 0.14285714285714285,
#   'thing': 0.14285714285714285,
#   'laugh': 0.14285714285714285,
#   'waitress': 0.14285714285714285,
#   'whole': 0.14285714285714285,
#   'plate': 0.14285714285714285,
#   'pop': 0.14285714285714285,
#   'earth': 0.14285714285714285,
#   'death': 0.14285714285714285,
#   'lifetime': 0.14285714285714285,
#   'insubstantial': 0.14285714285714285,
#   'quiet': 0.14285714285714285,
#   'silver': 0.14285714285714285,
#   'cream': 0.14285714285714285,
#   'length': 0.14285714285714285,
#   'leg': 0.125,
#   'half': 0.125,
#   'break': 0.125,
#   'jug': 0.125,
#   'sharp': 0.125,
#   'veil': 0.125,
#   'platform': 0.125,
#   'parasol': 0.125,
#   'mist': 0.125,
#   'vague': 0.125,
#   'grass': 0.125,
#   'company': 0.125,
#   'repulsive': 0.125,
#   'mask': 0.125,
#   'movement': 0.125,
#   'depth': 0.125,
#   'vast': 0.125,
#   'wave': 0.125,
#   'poplar': 0.125,
#   'stern': 0.1111111111111111,
#   'coal': 0.1111111111111111,
#   'thought': 0.1111111111111111,
#   'bay': 0.1111111111111111,
#   'edge': 0.1111111111111111,
#   'way': 0.1111111111111111,
#   'plantain': 0.1111111111111111,
#   'impropriety': 0.1111111111111111,
#   'stiff': 0.1111111111111111,
#   'summer': 0.1111111111111111,
#   'turbot': 0.1111111111111111,
#   'bunch': 0.1111111111111111,
#   'liqueur': 0.1111111111111111,
#   'boy': 0.1111111111111111,
#   'laundry': 0.1111111111111111,
#   'scissor': 0.1,
#   'work': 0.1,
#   'daughter': 0.1,
#   'sound': 0.1,
#   'scrap': 0.1,
#   'lugubrious': 0.1,
#   'crackle': 0.1,
#   'cold': 0.1,
#   'iris': 0.1,
#   'leave': 0.1,
#   'enormous': 0.1,
#   'evening': 0.1,
#   'looking': 0.1,
#   'pleased': 0.1,
#   'wicker': 0.1},
#  'brown': {'paper': 6.0,
#   'stocking': 4.0,
#   'reddish': 3.0,
#   'eye': 2.8194444444444446,
#   'parcel': 1.6666666666666665,
#   'something': 1.342857142857143,
#   'boot': 1.3333333333333333,
#   'large': 1.2,
#   'hairy': 1.0,
#   'huge': 1.0,
#   'pot': 1.0,
#   'great': 1.0,
#   'dish': 1.0,
#   'mere': 1.0,
#   'sail': 1.0,
#   'spot': 1.0,
#   'speck': 1.0,
#   'shoe': 1.0,
#   'cow': 1.0,
#   'dark': 1.0,
#   'wood': 1.0,
#   'tobacco': 1.0,
#   'canvas': 0.75,
#   'hand': 0.7,
#   'red': 0.7,
#   'boat': 0.503968253968254,
#   'dirt': 0.5,
#   'yellow': 0.5,
#   'blue': 0.5,
#   'nervous': 0.5,
#   'greyish': 0.5,
#   'rock': 0.5,
#   'film': 0.5,
#   'cream': 0.5,
#   'department': 0.5,
#   'petticoat': 0.5,
#   'decorous': 0.5,
#   'little': 0.44285714285714284,
#   'field': 0.34285714285714286,
#   'long': 0.3333333333333333,
#   'confusion': 0.3333333333333333,
#   'meat': 0.3333333333333333,
#   'leather': 0.3333333333333333,
#   'cardboard': 0.3333333333333333,
#   'white': 0.3333333333333333,
#   'line': 0.3333333333333333,
#   'water': 0.3333333333333333,
#   'black': 0.3333333333333333,
#   'mask': 0.3333333333333333,
#   'bay': 0.2857142857142857,
#   'twist': 0.25,
#   'suffusion': 0.25,
#   'wonderful': 0.25,
#   'cave': 0.25,
#   'middle': 0.25,
#   'nosed': 0.25,
#   'shabby': 0.25,
#   'adventurous': 0.25,
#   'fruit': 0.25,
#   'turbot': 0.25,
#   'depth': 0.25,
#   'striped': 0.25,
#   'door': 0.2,
#   'window': 0.2,
#   'brush': 0.2,
#   'incongruous': 0.2,
#   'row': 0.2,
#   'overcoat': 0.2,
#   'thrush': 0.2,
#   'whisker': 0.2,
#   'head': 0.16666666666666666,
#   'juice': 0.16666666666666666,
#   'wall': 0.16666666666666666,
#   'arm': 0.16666666666666666,
#   'sailing': 0.16666666666666666,
#   'shadow': 0.16666666666666666,
#   'beak': 0.16666666666666666,
#   'sort': 0.16666666666666666,
#   'shiny': 0.14285714285714285,
#   'number': 0.14285714285714285,
#   'path': 0.14285714285714285,
#   'mind': 0.14285714285714285,
#   'left': 0.14285714285714285,
#   'ready': 0.14285714285714285,
#   'sunburnt': 0.14285714285714285,
#   'well': 0.14285714285714285,
#   'saucer': 0.14285714285714285,
#   'casserole': 0.14285714285714285,
#   'frivolous': 0.14285714285714285,
#   'work': 0.125,
#   'illegal': 0.125,
#   'moment': 0.125,
#   'gaze': 0.125,
#   'voice': 0.125,
#   'girl': 0.125,
#   'oil': 0.125,
#   'flourish': 0.125,
#   'leave': 0.125,
#   'tread': 0.125,
#   'stroke': 0.125,
#   'play': 0.125,
#   'green': 0.125,
#   'faced': 0.125,
#   'hazel': 0.125,
#   'face': 0.125,
#   'battleship': 0.125,
#   'milk': 0.1111111111111111,
#   'world': 0.1111111111111111,
#   'cloak': 0.1111111111111111,
#   'military': 0.1111111111111111,
#   'hedge': 0.1111111111111111,
#   'silence': 0.1111111111111111,
#   'lawn': 0.1111111111111111,
#   'usual': 0.1111111111111111,
#   'needle': 0.1111111111111111,
#   'step': 0.1111111111111111,
#   'side': 0.1111111111111111,
#   'hour': 0.1111111111111111,
#   'sweet': 0.1111111111111111,
#   'mat': 0.1111111111111111,
#   'chicken': 0.1111111111111111,
#   'solid': 0.1111111111111111,
#   'olive': 0.1,
#   'firm': 0.1,
#   'child': 0.1,
#   'decisive': 0.1,
#   'running': 0.1,
#   'man': 0.1,
#   'love': 0.1,
#   'pale': 0.1,
#   'mist': 0.1,
#   'box': 0.1,
#   'unwieldy': 0.1},
#  'grey': {'hair': 4.0,
#   'cloak': 3.5,
#   'hat': 3.0,
#   'green': 2.611111111111111,
#   'dress': 2.0,
#   'suit': 2.0,
#   'silver': 1.8333333333333333,
#   'nurse': 1.7,
#   'man': 1.5833333333333333,
#   'motor': 1.4583333333333333,
#   'fur': 1.3333333333333333,
#   'white': 1.3333333333333333,
#   'little': 1.3,
#   'dark': 1.25,
#   'paper': 1.25,
#   'window': 1.2,
#   'rug': 1.2,
#   'church': 1.1666666666666667,
#   'car': 1.1428571428571428,
#   'blue': 1.0833333333333333,
#   'wall': 1.0456349206349205,
#   'something': 1.0,
#   'old': 1.0,
#   'upholstery': 1.0,
#   'pellet': 1.0,
#   'elderly': 1.0,
#   'horse': 1.0,
#   'room': 1.0,
#   'tide': 1.0,
#   'great': 1.0,
#   'building': 1.0,
#   'hand': 0.8527777777777779,
#   'suavity': 0.7916666666666666,
#   'grey': 0.7,
#   'coloured': 0.7,
#   'light': 0.6944444444444444,
#   'purple': 0.6666666666666666,
#   'pane': 0.6428571428571428,
#   'sober': 0.6190476190476191,
#   'same': 0.6111111111111112,
#   'day': 0.6,
#   'flower': 0.5928571428571429,
#   'eyed': 0.5,
#   'thick': 0.5,
#   'woman': 0.5,
#   'dove': 0.5,
#   'island': 0.5,
#   'plain': 0.5,
#   'haired': 0.5,
#   'dogged': 0.5,
#   'marble': 0.5,
#   'shape': 0.5,
#   'sheet': 0.5,
#   'quarter': 0.47619047619047616,
#   'red': 0.4583333333333333,
#   'yellow': 0.45238095238095233,
#   'dead': 0.45,
#   'eye': 0.4361111111111111,
#   'clean': 0.3666666666666667,
#   'water': 0.3611111111111111,
#   'banana': 0.3611111111111111,
#   'cheek': 0.3333333333333333,
#   'lemon': 0.3333333333333333,
#   'leave': 0.3333333333333333,
#   'lady': 0.3333333333333333,
#   'alone': 0.3333333333333333,
#   'clothe': 0.3333333333333333,
#   'mesh': 0.3333333333333333,
#   'morning': 0.3333333333333333,
#   'moth': 0.3333333333333333,
#   'square': 0.3333333333333333,
#   'upright': 0.3333333333333333,
#   'house': 0.3333333333333333,
#   'powerful': 0.3333333333333333,
#   'initial': 0.3333333333333333,
#   'ripple': 0.3333333333333333,
#   'service': 0.3333333333333333,
#   'stateliness': 0.3333333333333333,
#   'bright': 0.325,
#   'look': 0.325,
#   'sea': 0.30952380952380953,
#   'somnolence': 0.25,
#   'soft': 0.25,
#   'air': 0.25,
#   'rumour': 0.25,
#   'plate': 0.25,
#   'knitting': 0.25,
#   'cart': 0.25,
#   'bristle': 0.25,
#   'front': 0.25,
#   'dapper': 0.25,
#   'serious': 0.25,
#   'contented': 0.25,
#   'garden': 0.25,
#   'distinguished': 0.25,
#   'feeling': 0.2222222222222222,
#   'gardening': 0.2,
#   'boot': 0.2,
#   'good': 0.2,
#   'poker': 0.2,
#   'male': 0.2,
#   'time': 0.2,
#   'low': 0.2,
#   'weariness': 0.2,
#   'picture': 0.2,
#   'stream': 0.2,
#   'omnibus': 0.2,
#   'glass': 0.16666666666666666,
#   'sailing': 0.16666666666666666,
#   'puckered': 0.16666666666666666,
#   'child': 0.16666666666666666,
#   'telescope': 0.16666666666666666,
#   'hot': 0.16666666666666666,
#   'importance': 0.16666666666666666,
#   'baby': 0.16666666666666666,
#   'brewer': 0.16666666666666666,
#   'straw': 0.16666666666666666,
#   'extraordinary': 0.16666666666666666,
#   'patient': 0.16666666666666666,
#   'round': 0.16666666666666666,
#   'treasure': 0.16666666666666666,
#   'husband': 0.14285714285714285,
#   'whitening': 0.14285714285714285,
#   'inconspicuous': 0.14285714285714285,
#   'face': 0.14285714285714285,
#   'shoe': 0.14285714285714285,
#   'evening': 0.14285714285714285,
#   'more': 0.14285714285714285,
#   'beautiful': 0.14285714285714285,
#   'asleep': 0.14285714285714285,
#   'branch': 0.14285714285714285,
#   'distinction': 0.14285714285714285,
#   'splendid': 0.14285714285714285,
#   'shadow': 0.14285714285714285,
#   'ear': 0.14285714285714285,
#   'walking': 0.14285714285714285,
#   'view': 0.125,
#   'boat': 0.125,
#   'symbol': 0.125,
#   'opposite': 0.125,
#   'way': 0.125,
#   'common': 0.125,
#   'bed': 0.125,
#   'mast': 0.125,
#   'rest': 0.125,
#   'path': 0.125,
#   'panel': 0.125,
#   'dictionary': 0.125,
#   'end': 0.1111111111111111,
#   'young': 0.1111111111111111,
#   'misty': 0.1111111111111111,
#   'blind': 0.1111111111111111,
#   'nothing': 0.1111111111111111,
#   'circulation': 0.1111111111111111,
#   'dawn': 0.1111111111111111,
#   'people': 0.1111111111111111,
#   'broad': 0.1111111111111111,
#   'science': 0.1111111111111111,
#   'onerous': 0.1111111111111111,
#   'ring': 0.1111111111111111,
#   'lion': 0.1111111111111111,
#   'year': 0.1,
#   'word': 0.1,
#   'tail': 0.1,
#   'presence': 0.1,
#   'top': 0.1},
#  'yellow': {'red': 2.7857142857142856,
#   'curtain': 2.5,
#   'flower': 2.361111111111111,
#   'thin': 2.25,
#   'light': 1.5166666666666666,
#   'slipper': 1.5,
#   'beard': 1.45,
#   'veil': 1.4166666666666665,
#   'hat': 1.3333333333333333,
#   'harvest': 1.125,
#   'bee': 1.125,
#   'sheet': 1.1111111111111112,
#   'cat': 1.0,
#   'boot': 1.0,
#   'meat': 1.0,
#   'rose': 1.0,
#   'haze': 1.0,
#   'beam': 1.0,
#   'stain': 1.0,
#   'dressing': 1.0,
#   'glove': 1.0,
#   'butterfly': 1.0,
#   'awning': 1.0,
#   'lamp': 1.0,
#   'varnish': 1.0,
#   'bright': 1.0,
#   'eye': 0.8333333333333333,
#   'purple': 0.75,
#   'blue': 0.75,
#   'moon': 0.7222222222222222,
#   'white': 0.6,
#   'bowl': 0.5928571428571429,
#   'canary': 0.5,
#   'moustache': 0.5,
#   'green': 0.5,
#   'brown': 0.5,
#   'dahlia': 0.5,
#   'propriety': 0.5,
#   'hall': 0.5,
#   'banana': 0.5,
#   'omnibus': 0.5,
#   'chintz': 0.5,
#   'room': 0.45,
#   'yellow': 0.4,
#   'table': 0.33611111111111114,
#   'dress': 0.3333333333333333,
#   'dish': 0.3333333333333333,
#   'window': 0.3333333333333333,
#   'gleam': 0.3333333333333333,
#   'tower': 0.3333333333333333,
#   'gown': 0.3333333333333333,
#   'full': 0.3333333333333333,
#   'little': 0.3333333333333333,
#   'hung': 0.3333333333333333,
#   'evening': 0.3333333333333333,
#   'wall': 0.325,
#   'tall': 0.30000000000000004,
#   'grey': 0.2857142857142857,
#   'leave': 0.26666666666666666,
#   'streak': 0.25,
#   'shirt': 0.25,
#   'arm': 0.25,
#   'shell': 0.25,
#   'staircase': 0.25,
#   'tree': 0.25,
#   'circle': 0.25,
#   'man': 0.25,
#   'cheese': 0.25,
#   'penknife': 0.25,
#   'bed': 0.25,
#   'damned': 0.25,
#   'side': 0.25,
#   'fruit': 0.2,
#   'confusion': 0.2,
#   'bay': 0.2,
#   'abloom': 0.2,
#   'word': 0.2,
#   'autumn': 0.2,
#   'old': 0.2,
#   'pincushion': 0.2,
#   'pipe': 0.2,
#   'cigarette': 0.2,
#   'bird': 0.2,
#   'vivid': 0.16666666666666666,
#   'demon': 0.16666666666666666,
#   'quiet': 0.16666666666666666,
#   'dark': 0.16666666666666666,
#   'sharp': 0.16666666666666666,
#   'faint': 0.16666666666666666,
#   'inscrutable': 0.16666666666666666,
#   'misty': 0.16666666666666666,
#   'grass': 0.16666666666666666,
#   'speed': 0.16666666666666666,
#   'baby': 0.16666666666666666,
#   'cover': 0.16666666666666666,
#   'book': 0.14285714285714285,
#   'entire': 0.14285714285714285,
#   'ridge': 0.14285714285714285,
#   'curved': 0.14285714285714285,
#   'edge': 0.14285714285714285,
#   'paper': 0.14285714285714285,
#   'fishing': 0.14285714285714285,
#   'smoke': 0.14285714285714285,
#   'lady': 0.14285714285714285,
#   'caravan': 0.14285714285714285,
#   'sharpened': 0.14285714285714285,
#   'milk': 0.125,
#   'gentleman': 0.125,
#   'child': 0.125,
#   'obvious': 0.125,
#   'horny': 0.125,
#   'shape': 0.125,
#   'basin': 0.125,
#   'sand': 0.125,
#   'end': 0.125,
#   'silvery': 0.125,
#   'careless': 0.125,
#   'tea': 0.125,
#   'happy': 0.125,
#   'malachite': 0.125,
#   'garish': 0.125,
#   'chair': 0.125,
#   'husband': 0.1111111111111111,
#   'thick': 0.1111111111111111,
#   'shiny': 0.1111111111111111,
#   'wine': 0.1111111111111111,
#   'mind': 0.1111111111111111,
#   'firm': 0.1111111111111111,
#   'indian': 0.1111111111111111,
#   'poetry': 0.1111111111111111,
#   'plate': 0.1111111111111111,
#   'vine': 0.1111111111111111,
#   'right': 0.1111111111111111,
#   'rod': 0.1111111111111111,
#   'morning': 0.1111111111111111,
#   'new': 0.1111111111111111,
#   'long': 0.1,
#   'jug': 0.1,
#   'bulk': 0.1,
#   'leaf': 0.1,
#   'buccaneer': 0.1,
#   'roar': 0.1},
#  'green': {'dress': 5.333333333333333,
#   'shawl': 4.0,
#   'light': 3.642857142857143,
#   'blue': 2.625,
#   'grey': 2.611111111111111,
#   'paint': 2.0,
#   'grass': 1.2916666666666665,
#   'mound': 1.2,
#   'wall': 1.2,
#   'sea': 1.1428571428571428,
#   'fold': 1.1428571428571428,
#   'window': 1.125,
#   'silk': 1.1111111111111112,
#   'faint': 1.1,
#   'silver': 1.0,
#   'sand': 1.0,
#   'spear': 1.0,
#   'room': 1.0,
#   'cave': 1.0,
#   'cascade': 1.0,
#   'vague': 1.0,
#   'eye': 1.0,
#   'swirls': 1.0,
#   'cloak': 1.0,
#   'brooch': 1.0,
#   'stuff': 1.0,
#   'linoleum': 1.0,
#   'shone': 1.0,
#   'vivid': 1.0,
#   'moss': 1.0,
#   'chair': 1.0,
#   'blade': 1.0,
#   'glossy': 1.0,
#   'trumpet': 1.0,
#   'mermaid': 1.0,
#   'frill': 1.0,
#   'soft': 0.8666666666666667,
#   'wave': 0.85,
#   'summer': 0.6666666666666666,
#   'hillside': 0.6428571428571428,
#   'picture': 0.628968253968254,
#   'frame': 0.6111111111111112,
#   'little': 0.6,
#   'pink': 0.6,
#   'mind': 0.5694444444444444,
#   'rock': 0.5583333333333333,
#   'somnolence': 0.5,
#   'dune': 0.5,
#   'deep': 0.5,
#   'yellow': 0.5,
#   'whole': 0.5,
#   'tube': 0.5,
#   'smoky': 0.5,
#   'tuft': 0.5,
#   'coat': 0.5,
#   'length': 0.5,
#   'end': 0.5,
#   'earth': 0.5,
#   'flowery': 0.5,
#   'leave': 0.47619047619047616,
#   'square': 0.45,
#   'hollow': 0.43333333333333335,
#   'brush': 0.41666666666666663,
#   'purple': 0.3611111111111111,
#   'tree': 0.35,
#   'red': 0.35,
#   'pleat': 0.3333333333333333,
#   'house': 0.3333333333333333,
#   'like': 0.3333333333333333,
#   'change': 0.3333333333333333,
#   'flower': 0.3333333333333333,
#   'old': 0.3333333333333333,
#   'eighteenth': 0.3333333333333333,
#   'artificial': 0.3333333333333333,
#   'curtain': 0.3333333333333333,
#   'bud': 0.3333333333333333,
#   'gramophone': 0.3333333333333333,
#   'accord': 0.3333333333333333,
#   'brown': 0.325,
#   'edge': 0.3111111111111111,
#   'water': 0.3111111111111111,
#   'hyacinth': 0.3111111111111111,
#   'colour': 0.25396825396825395,
#   'ear': 0.25,
#   'low': 0.25,
#   'gilt': 0.25,
#   'shoulder': 0.25,
#   'plant': 0.25,
#   'hedge': 0.25,
#   'sunlight': 0.25,
#   'bubble': 0.25,
#   'cloud': 0.25,
#   'gravity': 0.25,
#   'streak': 0.25,
#   'transparent': 0.25,
#   'lovely': 0.25,
#   'parasol': 0.25,
#   'sound': 0.25,
#   'tap': 0.25,
#   'pause': 0.25,
#   'knife': 0.25,
#   'example': 0.25,
#   'nothing': 0.25,
#   'own': 0.25,
#   'white': 0.225,
#   'hand': 0.225,
#   'arm': 0.2222222222222222,
#   'wild': 0.2,
#   'lemon': 0.2,
#   'use': 0.2,
#   'alone': 0.2,
#   'early': 0.2,
#   'spray': 0.2,
#   'vivacious': 0.2,
#   'century': 0.2,
#   'black': 0.2,
#   'ceiling': 0.2,
#   'gay': 0.2,
#   'cook': 0.2,
#   'dripping': 0.2,
#   'softness': 0.2,
#   'gentle': 0.2,
#   'evening': 0.2,
#   'bed': 0.2,
#   'globe': 0.2,
#   'church': 0.2,
#   'primeval': 0.2,
#   'clod': 0.16666666666666666,
#   'path': 0.16666666666666666,
#   'leaf': 0.16666666666666666,
#   'power': 0.16666666666666666,
#   'opposite': 0.16666666666666666,
#   'pattern': 0.16666666666666666,
#   'eddy': 0.16666666666666666,
#   'common': 0.16666666666666666,
#   'line': 0.16666666666666666,
#   'setting': 0.16666666666666666,
#   'park': 0.16666666666666666,
#   'cloth': 0.16666666666666666,
#   'pen': 0.16666666666666666,
#   'needle': 0.16666666666666666,
#   'siren': 0.16666666666666666,
#   'station': 0.16666666666666666,
#   'toil': 0.16666666666666666,
#   'ring': 0.16666666666666666,
#   'coloured': 0.14285714285714285,
#   'greenery': 0.14285714285714285,
#   'thick': 0.14285714285714285,
#   'cock': 0.14285714285714285,
#   'briar': 0.14285714285714285,
#   'pale': 0.14285714285714285,
#   'mass': 0.14285714285714285,
#   'space': 0.14285714285714285,
#   'impression': 0.14285714285714285,
#   'body': 0.14285714285714285,
#   'poker': 0.14285714285714285,
#   'feeling': 0.14285714285714285,
#   'man': 0.14285714285714285,
#   'high': 0.14285714285714285,
#   'diamond': 0.14285714285714285,
#   'insensitive': 0.14285714285714285,
#   'plume': 0.14285714285714285,
#   'bathroom': 0.14285714285714285,
#   'play': 0.14285714285714285,
#   'morning': 0.14285714285714285,
#   'cow': 0.14285714285714285,
#   'more': 0.14285714285714285,
#   'sailing': 0.125,
#   'quiet': 0.125,
#   'cataract': 0.125,
#   'people': 0.125,
#   'entire': 0.125,
#   'hot': 0.125,
#   'year': 0.125,
#   'omnibus': 0.125,
#   'dressed': 0.125,
#   'parsley': 0.125,
#   'need': 0.1111111111111111,
#   'palette': 0.1111111111111111,
#   'life': 0.1111111111111111,
#   'empty': 0.1111111111111111,
#   'difficult': 0.1111111111111111,
#   'cluster': 0.1111111111111111,
#   'one': 0.1111111111111111,
#   'paste': 0.1111111111111111,
#   'horse': 0.1111111111111111,
#   'slope': 0.1111111111111111,
#   'face': 0.1111111111111111,
#   'serious': 0.1111111111111111,
#   'exact': 0.1111111111111111,
#   'tip': 0.1,
#   'boat': 0.1,
#   'bright': 0.1,
#   'passion': 0.1,
#   'head': 0.1,
#   'night': 0.1,
#   'symbol': 0.1,
#   'place': 0.1,
#   'scene': 0.1,
#   'trail': 0.1,
#   'bird': 0.1,
#   'long': 0.1,
#   'knee': 0.1,
#   'dancing': 0.1,
#   'shield': 0.1,
#   'woman': 0.1},
#  'white': {'flower': 3.3666666666666667,
#   'smoke': 3.111111111111111,
#   'slip': 3.0,
#   'broad': 2.0,
#   'apron': 2.0,
#   'black': 1.9619047619047618,
#   'red': 1.9166666666666665,
#   'rose': 1.85,
#   'dress': 1.6666666666666665,
#   'wall': 1.5,
#   'uncompromising': 1.5,
#   'lozenge': 1.5,
#   'shawl': 1.5,
#   'snow': 1.5,
#   'house': 1.4166666666666665,
#   'blind': 1.375,
#   'canvas': 1.3666666666666667,
#   'shape': 1.3333333333333333,
#   'glove': 1.3333333333333333,
#   'grey': 1.3333333333333333,
#   'waistcoat': 1.25,
#   'violet': 1.15,
#   'ribbon': 1.1428571428571428,
#   'dawn': 1.1428571428571428,
#   'window': 1.1285714285714286,
#   'water': 1.125,
#   'light': 1.125,
#   'pale': 1.0333333333333332,
#   'milk': 1.0,
#   'deal': 1.0,
#   'scientific': 1.0,
#   'foam': 1.0,
#   'long': 1.0,
#   'robe': 1.0,
#   'stare': 1.0,
#   'lamp': 1.0,
#   'difficult': 1.0,
#   'space': 1.0,
#   'splinter': 1.0,
#   'moth': 1.0,
#   'bust': 1.0,
#   'thing': 1.0,
#   'poured': 1.0,
#   'band': 1.0,
#   'frock': 1.0,
#   'aproned': 1.0,
#   'mound': 1.0,
#   'cap': 1.0,
#   'marble': 1.0,
#   'mountainous': 1.0,
#   'shell': 1.0,
#   'table': 0.925,
#   'pure': 0.8928571428571428,
#   'little': 0.851190476190476,
#   'white': 0.8333333333333333,
#   'coat': 0.8333333333333333,
#   'man': 0.7916666666666666,
#   'hair': 0.75,
#   'something': 0.75,
#   'fountain': 0.7361111111111112,
#   'wave': 0.6944444444444444,
#   'blue': 0.6761904761904762,
#   'cloud': 0.6428571428571428,
#   'door': 0.6333333333333333,
#   'girl': 0.625,
#   'hard': 0.625,
#   'hand': 0.6178571428571429,
#   'yellow': 0.6,
#   'plate': 0.6,
#   'pane': 0.5111111111111111,
#   'old': 0.503968253968254,
#   'fat': 0.5,
#   'puckered': 0.5,
#   'shirt': 0.5,
#   'circle': 0.5,
#   'wreath': 0.5,
#   'cluster': 0.5,
#   'spray': 0.5,
#   'washed': 0.5,
#   'valley': 0.5,
#   'dab': 0.5,
#   'image': 0.5,
#   'glow': 0.5,
#   'magical': 0.5,
#   'bar': 0.5,
#   'stiff': 0.5,
#   'hour': 0.5,
#   'imperishable': 0.5,
#   'pin': 0.5,
#   'bald': 0.5,
#   'pallor': 0.5,
#   'stone': 0.5,
#   'eminent': 0.5,
#   'woman': 0.4861111111111111,
#   'rock': 0.47619047619047616,
#   'illness': 0.45,
#   'sheet': 0.4444444444444444,
#   'eye': 0.4361111111111111,
#   'cheek': 0.375,
#   'tree': 0.375,
#   'green': 0.3678571428571429,
#   'forehead': 0.3611111111111111,
#   'bed': 0.35,
#   'wedding': 0.35,
#   'ear': 0.35,
#   'bright': 0.3333333333333333,
#   'silver': 0.3333333333333333,
#   'aslant': 0.3333333333333333,
#   'brown': 0.3333333333333333,
#   'shade': 0.3333333333333333,
#   'straight': 0.3333333333333333,
#   'ruffled': 0.3333333333333333,
#   'arm': 0.3333333333333333,
#   'pattern': 0.3333333333333333,
#   'dead': 0.3333333333333333,
#   'side': 0.3333333333333333,
#   'dinner': 0.3333333333333333,
#   'word': 0.3333333333333333,
#   'maid': 0.3333333333333333,
#   'audience': 0.3333333333333333,
#   'wood': 0.3333333333333333,
#   'gold': 0.3333333333333333,
#   'print': 0.3333333333333333,
#   'admirable': 0.3333333333333333,
#   'stark': 0.3111111111111111,
#   'pearl': 0.3111111111111111,
#   'delight': 0.2777777777777778,
#   'surface': 0.2777777777777778,
#   'hall': 0.2777777777777778,
#   'moustache': 0.26785714285714285,
#   'emotion': 0.26666666666666666,
#   'stair': 0.25,
#   'nothing': 0.25,
#   'legged': 0.25,
#   'face': 0.25,
#   'top': 0.25,
#   'raven': 0.25,
#   'glass': 0.25,
#   'country': 0.25,
#   'circular': 0.25,
#   'thick': 0.25,
#   'room': 0.25,
#   'tie': 0.25,
#   'pleasurable': 0.25,
#   'swing': 0.25,
#   'billowing': 0.25,
#   'egg': 0.25,
#   'clothe': 0.25,
#   'beach': 0.25,
#   'fox': 0.25,
#   'horizon': 0.25,
#   'anglo': 0.25,
#   'branch': 0.2361111111111111,
#   'evening': 0.2361111111111111,
#   'sight': 0.2,
#   'impersonality': 0.2,
#   'night': 0.2,
#   'curtain': 0.2,
#   'mountain': 0.2,
#   'earwig': 0.2,
#   'field': 0.2,
#   'uppermost': 0.2,
#   'tinged': 0.2,
#   'baby': 0.2,
#   'brooch': 0.2,
#   'stroke': 0.2,
#   'shoulder': 0.2,
#   'spruce': 0.2,
#   'coral': 0.2,
#   'handmaiden': 0.2,
#   'verge': 0.2,
#   'stick': 0.2,
#   'beard': 0.16666666666666666,
#   'chinese': 0.16666666666666666,
#   'gentleman': 0.16666666666666666,
#   'hollow': 0.16666666666666666,
#   'mushroom': 0.16666666666666666,
#   'iris': 0.16666666666666666,
#   'deep': 0.16666666666666666,
#   'part': 0.16666666666666666,
#   'head': 0.16666666666666666,
#   'spirit': 0.16666666666666666,
#   'vast': 0.16666666666666666,
#   'motherliness': 0.16666666666666666,
#   'back': 0.16666666666666666,
#   'sensitive': 0.16666666666666666,
#   'rest': 0.16666666666666666,
#   'verandah': 0.16666666666666666,
#   'terrier': 0.16666666666666666,
#   'tower': 0.14285714285714285,
#   'leave': 0.14285714285714285,
#   'running': 0.14285714285714285,
#   'bowl': 0.14285714285714285,
#   'orange': 0.14285714285714285,
#   'way': 0.14285714285714285,
#   'sister': 0.14285714285714285,
#   'railing': 0.14285714285714285,
#   't': 0.14285714285714285,
#   'clean': 0.14285714285714285,
#   'party': 0.14285714285714285,
#   'return': 0.14285714285714285,
#   'elderly': 0.14285714285714285,
#   'brotherly': 0.14285714285714285,
#   'bunch': 0.14285714285714285,
#   'heat': 0.14285714285714285,
#   'fine': 0.14285714285714285,
#   'bare': 0.14285714285714285,
#   'lighthouse': 0.14285714285714285,
#   'poet': 0.14285714285714285,
#   'flamingo': 0.125,
#   'cleanliness': 0.125,
#   'church': 0.125,
#   'sound': 0.125,
#   'garden': 0.125,
#   'brush': 0.125,
#   'mark': 0.125,
#   'wicker': 0.125,
#   'air': 0.125,
#   'carnation': 0.125,
#   'footman': 0.125,
#   'ancestor': 0.125,
#   'dog': 0.125,
#   'waxed': 0.125,
#   'love': 0.125,
#   'certain': 0.125,
#   'spectacle': 0.125,
#   'great': 0.125,
#   'age': 0.125,
#   'honest': 0.1111111111111111,
#   'fashionable': 0.1111111111111111,
#   'napkin': 0.1111111111111111,
#   'book': 0.1111111111111111,
#   'blankly': 0.1111111111111111,
#   'form': 0.1111111111111111,
#   'beauty': 0.1111111111111111,
#   'tuft': 0.1111111111111111,
#   'cherry': 0.1111111111111111,
#   'background': 0.1111111111111111,
#   'twisted': 0.1111111111111111,
#   'sky': 0.1111111111111111,
#   'jagged': 0.1111111111111111,
#   'narrow': 0.1111111111111111,
#   'chow': 0.1111111111111111,
#   'laugh': 0.1111111111111111,
#   'adventurousness': 0.1111111111111111,
#   'coldness': 0.1111111111111111,
#   'tub': 0.1111111111111111,
#   'necessity': 0.1111111111111111,
#   'tissue': 0.1111111111111111,
#   'dignity': 0.1111111111111111,
#   'horn': 0.1111111111111111,
#   'bedroom': 0.1111111111111111,
#   'treasure': 0.1111111111111111,
#   'chip': 0.1111111111111111,
#   'free': 0.1111111111111111,
#   'knee': 0.1111111111111111,
#   'square': 0.1111111111111111,
#   'thinker': 0.1111111111111111,
#   'full': 0.1111111111111111,
#   'charm': 0.1,
#   'king': 0.1,
#   'furtive': 0.1,
#   'underworld': 0.1,
#   'change': 0.1,
#   'pie': 0.1,
#   'agitation': 0.1,
#   'nobody': 0.1,
#   'relief': 0.1,
#   'o': 0.1,
#   'true': 0.1,
#   'thin': 0.1,
#   'respectability': 0.1,
#   'tawny': 0.1,
#   'plane': 0.1,
#   'factory': 0.1,
#   'passing': 0.1,
#   'paper': 0.1,
#   'more': 0.1,
#   'past': 0.1,
#   'bauble': 0.1,
#   'friend': 0.1},
#  'black': {'dress': 3.0,
#   'little': 2.1,
#   'parasol': 2.0,
#   'wing': 2.0,
#   'white': 1.9619047619047618,
#   'wave': 1.378968253968254,
#   'sky': 1.3333333333333333,
#   'long': 1.2,
#   'great': 1.1428571428571428,
#   'rock': 1.1,
#   'old': 1.1,
#   'pitch': 1.0,
#   'knickerbocker': 1.0,
#   'nice': 1.0,
#   'flat': 1.0,
#   'stone': 1.0,
#   'sudden': 1.0,
#   'cork': 1.0,
#   'horse': 1.0,
#   'branch': 1.0,
#   'collecting': 1.0,
#   'cloak': 1.0,
#   'thin': 1.0,
#   'veil': 1.0,
#   'body': 1.0,
#   'blue': 0.95,
#   'pig': 0.8,
#   'half': 0.6666666666666666,
#   'sea': 0.6166666666666667,
#   'boot': 0.5833333333333333,
#   'bitter': 0.5,
#   'skirt': 0.5,
#   'pane': 0.5,
#   'book': 0.5,
#   'fierce': 0.5,
#   'winged': 0.5,
#   'bit': 0.5,
#   'uppermost': 0.5,
#   'discreet': 0.5,
#   'iron': 0.5,
#   'figure': 0.5,
#   'eye': 0.5,
#   'whisker': 0.5,
#   'face': 0.45,
#   'jewel': 0.43333333333333335,
#   'red': 0.3611111111111111,
#   'invitation': 0.34285714285714286,
#   'erect': 0.3333333333333333,
#   'high': 0.3333333333333333,
#   'short': 0.3333333333333333,
#   'raven': 0.3333333333333333,
#   'harpy': 0.3333333333333333,
#   'spread': 0.3333333333333333,
#   'omnibus': 0.3333333333333333,
#   'lozenge': 0.3333333333333333,
#   'box': 0.3333333333333333,
#   'brown': 0.3333333333333333,
#   'sock': 0.3333333333333333,
#   'straight': 0.30000000000000004,
#   'marriage': 0.25,
#   'sad': 0.25,
#   'way': 0.25,
#   'row': 0.25,
#   'coat': 0.25,
#   'dice': 0.25,
#   'delphinium': 0.25,
#   'spectacular': 0.25,
#   'enchanting': 0.25,
#   'hall': 0.25,
#   'slimness': 0.25,
#   'sunburnt': 0.25,
#   'sun': 0.25,
#   'shawl': 0.25,
#   'shape': 0.225,
#   'chair': 0.2111111111111111,
#   'evening': 0.2,
#   'exquisite': 0.2,
#   'green': 0.2,
#   'image': 0.2,
#   'thick': 0.2,
#   'outline': 0.2,
#   'front': 0.2,
#   'laundry': 0.2,
#   'grenadier': 0.2,
#   'unfortunate': 0.16666666666666666,
#   'church': 0.16666666666666666,
#   'scimitar': 0.16666666666666666,
#   'top': 0.16666666666666666,
#   'harmony': 0.16666666666666666,
#   'dog': 0.16666666666666666,
#   'blind': 0.16666666666666666,
#   'wind': 0.16666666666666666,
#   'blurred': 0.16666666666666666,
#   'hand': 0.16666666666666666,
#   'spectral': 0.16666666666666666,
#   'lunch': 0.16666666666666666,
#   'anybody': 0.14285714285714285,
#   'tower': 0.14285714285714285,
#   'air': 0.14285714285714285,
#   'ceremony': 0.14285714285714285,
#   'triumph': 0.14285714285714285,
#   'hard': 0.14285714285714285,
#   'stark': 0.14285714285714285,
#   'fish': 0.14285714285714285,
#   'dinner': 0.14285714285714285,
#   'throw': 0.14285714285714285,
#   'day': 0.14285714285714285,
#   'chow': 0.14285714285714285,
#   'shoulder': 0.14285714285714285,
#   'screen': 0.14285714285714285,
#   'bottle': 0.14285714285714285,
#   'necklace': 0.125,
#   'voice': 0.125,
#   'farm': 0.125,
#   'partial': 0.125,
#   'talon': 0.125,
#   'beak': 0.125,
#   'window': 0.125,
#   'carnation': 0.125,
#   'soldier': 0.125,
#   'tawny': 0.125,
#   'edge': 0.125,
#   'elegance': 0.125,
#   'cordial': 0.125,
#   'mountain': 0.1111111111111111,
#   'woman': 0.1111111111111111,
#   'gold': 0.1111111111111111,
#   'flame': 0.1111111111111111,
#   'duck': 0.1111111111111111,
#   'tore': 0.1111111111111111,
#   'dead': 0.1111111111111111,
#   'summer': 0.1111111111111111,
#   'lady': 0.1111111111111111,
#   'premeditation': 0.1111111111111111,
#   'statue': 0.1111111111111111,
#   'indescribable': 0.1,
#   'ruffled': 0.1,
#   'darkness': 0.1,
#   'stream': 0.1,
#   'candle': 0.1,
#   'commendation': 0.1,
#   'doubt': 0.1,
#   'pattern': 0.1,
#   'exalted': 0.1,
#   'young': 0.1,
#   'butler': 0.1,
#   'botanist': 0.1,
#   'desert': 0.1,
#   'fashion': 0.1,
#   'movement': 0.1,
#   'dozen': 0.1},
#  'orange': {'deep': 1.0,
#   'red': 0.3333333333333333,
#   'flower': 0.3333333333333333,
#   'violet': 0.2,
#   'white': 0.14285714285714285,
#   'glow': 0.1111111111111111}}
