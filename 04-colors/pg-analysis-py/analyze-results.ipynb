# %%
import sklearn
import pandas as pd
import json
import cufflinks as cf
import plotly.express as px
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
rawResults = open('pg-analysis-results').read()

# %%
lines = rawResults.split('\n')

# %%
relevantLines = [line for line in lines if line.startswith('[')]

# %%
len(lines)
# Out:
# 321

# %%
len(relevantLines)
# Out:
# 159

# %%
cleaned = [line[:line.rfind(']')+1] for line in relevantLines]

# %%
parsed = [json.loads(line) for line in cleaned]

# %%
parsedCleaned = [item[0][0] for item in parsed]

# %%
df = pd.DataFrame(parsedCleaned)

# %%
df
# Out:
#                                              statsList colorMapName textName
# 0    [{'parent': 'black', 'hex': '#1b2431', 'colorW...         XKCD       11
# 1    [{'parent': 'black', 'hex': '#1b2431', 'colorW...         XKCD       11
# 2    [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD       12
# 3    [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD       13
# 4    [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD       16
# ..                                                 ...          ...      ...
# 154  [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD      572
# 155  [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD      573
# 156  [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD      574
# 157  [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD      575
# 158  [{'parent': 'black', 'hex': '#000000', 'colorW...         XKCD      577
#
# [159 rows x 3 columns]

# %%
len(df.loc[0]['statsList'][0]['locations'])
# Out:
# 3

# %%
stats = pd.DataFrame(df.loc[0]['statsList'])

# %%
df['stats'] = df['statsList'].apply(pd.DataFrame)

# %%
def groupByParent(df): 
    try:
        return df.groupby('parent').sum()
    except:
        return

# %%
df['parentDist'] = df['stats'].apply(groupByParent)

# %%
df['parentDist'][0].to_dict()
# Out:
# {'nMatches': {'black': 3.461501183833405e-05,
#   'blue': 1.384600473533362e-05,
#   'green': 5.538401894133448e-05,
#   'grey': 0.0004223031444276754,
#   'orange': 1.384600473533362e-05,
#   'purple': 2.769200947066724e-05,
#   'red': 4.153801420600086e-05,
#   'white': 0.00024922808523600515,
#   'yellow': 0.000145383049721003}}

# %%
parentDists = {}
for i, row in df.iterrows():
    try:
        parentDists[row['textName']] = row['parentDist'].to_dict()['nMatches'] 
    except:
        continue

# %%
df2 = pd.DataFrame(parentDists)

# %%
df2 = df2.T

# %%
df2['name'] = df2.index

# %%
dfTidy = df2.melt(id_vars='name', var_name='color')

# %%
fig = px.bar(dfTidy, x='value', y='name', barmode='stack')

# %%
open('out.html', 'w').write(fig.to_html())
# Out:
# 3371774

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="f9ce1645-6dc0-4416-b078-769ea5af8f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f9ce1645-6dc0-4416-b078-769ea5af8f1f")) {
#                     Plotly.newPlot(
#                         'f9ce1645-6dc0-4416-b078-769ea5af8f1f',
#                         [{"alignmentgroup": "True", "hovertemplate": "value=%{x}<br>name=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [3.461501183833405e-05, 0.00012945382813463196, 0.00012255277428842794, 0.00011674151094646234, 0.00015322807474171622, 0.00015212794394737242, 0.00013859470202139064, 0.0003687192035665203, 0.0005541439949065915, 0.0001785306215722121, 0.00018037127623500216, 0.0002272368628688654, 7.168458781362007e-05, 0.00011972117351519942, 0.00018418085115027265, 0.00011860426500936975, 0.00035712180627355526, 0.00021393566347127779, 7.864027031232198e-05, 5.7830458231416076e-05, 0.00013736122664859146, 0.0001789267024301201, 0.00012887520584234266, 0.00024430414493549274, 5.537443500771781e-05, 0.0001443925227673785, 0.00010318414120446241, 9.11318906287124e-05, 2.6943491799555818e-05, 0.00032464432349852004, 0.0001886547735553171, 3.169970417383212e-05, 9.652642755691612e-05, 0.00018166966181996404, 5.683214292281024e-05, 0.00033974603983522316, 0.00013423569550869737, 9.404613475041924e-05, 1.585432143504258e-05, 0.0003747153604473525, 1.0388762327379583e-05, 0.00012307713493643453, 9.395258526197113e-05, 0.00020434558926055743, 0.00014064697609001404, 0.0010303429180945464, 0.00039439434175584363, 0.00022987514905966694, 0.0003339866027260869, 0.0004176014470797971, 0.0003383352950426732, 0.0004055926722923872, 0.0001798761144142907, 9.573136306733106e-05, 0.0011287048924727146, 0.00011569458263519593, 0.0001091319940769145, 8.271461488469189e-05, 0.00029966488694959417, 0.0001564107841119572, 2.0328095460736283e-06, 0.00028479715522243456, 0.00037945521073316167, 9.560200883721069e-05, 0.000367680853019579, null, 0.00019603816209555459, 0.0002204114127055665, 0.00011725244836567385, 0.00016577027923082591, 0.00010627274901033501, 0.00011151352950017697, 0.00027259687465519745, 0.00025188123799628476, 0.00022839292423985677, 9.72568174327442e-05, 0.00012094923156005266, 0.00044415966447742064, 0.0002182643617950061, 0.00012142250030355624, 0.000288511593775676, 0.0002156555539099911, 0.00016250385946666232, 0.00010634338278300632, 0.00020390816342895634, 0.00014983571163114457, 0.00014816337670715756, 0.00017018897053907358, 0.0001262599692767408, 0.0002439665202867545, 0.00010997873744409414, 2.828730281981978e-05, 8.60767919753476e-05, 0.00011718034267793301, 1.92124066036884e-05, 0.0002226386389357873, 9.130350977454796e-05, 5.3913753398491946e-05, 0.0001940126023838244, 0.00019583690475514712, 0.00024739507538273475, 0.00017510316889410518, 0.00016876459813773892, 0.00019437018734090936, 0.00021076789770731365, 0.0001714979651998183, 0.00027661607933188794, 0.0002845807456015534, 8.397333846503733e-05, 7.158846544617513e-05, 8.122157244964262e-05, 0.00010625793654958179, 0.0001010427612965807, 0.00021954157346039055, 0.00021006196828064278, 0.0005038455268890502, 0.00017308209889738049, 0.00013940029033715644, 0.00014011015557058654, 0.0001748420670013205, 4.650469136119232e-05, 0.00012772673776788405, 0.0003244875213385815, 0.0003415689399977229, 0.00040736431833795356, 0.00030005527333982574, 0.00026652129141680294, 0.00016234260377243626, 0.0002198796159102891, 0.00024373181903070704, 0.00030947168103169547, 0.00024370647078759072, 0.00018805885066658048, 4.712819623426861e-05, 0.00014712941319272664, 0.00037927873826606404, 6.230141424210329e-05, 0.00039926136647202675, 3.0067250416765498e-05, 2.257867256220895e-05, 1.384600473533362e-05, 2.4657872025644187e-05, null, 1.9456918491077057e-05, 1.259408833493558e-05, 2.390581976315852e-05, 2.8764938155382967e-05, 4.469323679594185e-05, 7.368936102481267e-05, null, null, 6.312135079690705e-06, 1.0240655401945725e-05, 0.00012178533167925459, 4.6045212787568155e-05, 2.6092938302061344e-05, 5.200803003983815e-05, 3.6976534427134436e-05, 4.635834550630915e-05, 2.1418688233857806e-06, 2.8242495198775813e-05, 3.7 ...
